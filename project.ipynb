# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATASET_PATH = '/content/drive/MyDrive/MyDataset'

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, LSTM, Dense, TimeDistributed, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
import os

# Check if the dataset path exists
print(f"Dataset Path Exists: {os.path.exists(DATASET_PATH)}")

# Print folders inside the dataset path
if os.path.exists(DATASET_PATH):
    print("Folders inside dataset:", os.listdir(DATASET_PATH))
# Out:
# Dataset Path Exists: True
# Folders inside dataset: ['normal', 'rash']

# %%
for category in ["normal", "rash"]:
    category_path = os.path.join(DATASET_PATH, category)
    print(f"Checking {category_path} ...")

    if os.path.exists(category_path):
        print(f"Videos inside '{category}':", os.listdir(category_path))
# Out:
# Checking /content/drive/MyDrive/MyDataset/normal ...
# Videos inside 'normal': ['video_791', 'video_792', 'video_793', 'video_794', 'video_795', 'video_796', 'video_797', 'video_798', 'video_799', 'video_800', 'video_801', 'video_802', 'video_803', 'video_804', 'video_805', 'video_806', 'video_807', 'video_808', 'video_809', 'video_810', 'video_811', 'video_812', 'video_813', 'video_814', 'video_815', 'video_816', 'video_817', 'video_818', 'video_819', 'video_820', 'video_821', 'video_822', 'video_823', 'video_824', 'video_825', 'video_826', 'video_827', 'video_828', 'video_829', 'video_830', 'video_831', 'video_832', 'video_833', 'video_834', 'video_835', 'video_836', 'video_837', 'video_838', 'video_839', 'video_840', 'video_841', 'video_842', 'video_843', 'video_844', 'video_845', 'video_846', 'video_847', 'video_848', 'video_849', 'video_850', 'video_851', 'video_852', 'video_853', 'video_854', 'video_855', 'video_856', 'video_857', 'video_858', 'video_859', 'video_860', 'video_861', 'video_862', 'video_863', 'video_864', 'video_865', 'video_866', 'video_867', 'video_868', 'video_869', 'video_870', 'video_871', 'video_872', 'video_873', 'video_874', 'video_875', 'video_876', 'video_877', 'video_878', 'video_879', 'video_880', 'video_881', 'video_882', 'video_883', 'video_884', 'video_885', 'video_886', 'video_887', 'video_888', 'video_889', 'video_890', 'video_891', 'video_892', 'video_893', 'video_894', 'video_895', 'video_896', 'video_897', 'video_898', 'video_899', 'video_900', 'video_901', 'video_902', 'video_903', 'video_904', 'video_905', 'video_906', 'video_907', 'video_908', 'video_909', 'video_910', 'video_911', 'video_912', 'video_913', 'video_914', 'video_915', 'video_916', 'video_917', 'video_918', 'video_919', 'video_920', 'video_921', 'video_922', 'video_923', 'video_924', 'video_925', 'video_926', 'video_927', 'video_928', 'video_929', 'video_930', 'video_931', 'video_932', 'video_933', 'video_934', 'video_935', 'video_936', 'video_937', 'video_938', 'video_939', 'video_940', 'video_941', 'video_942', 'video_943', 'video_944', 'video_945', 'video_946', 'video_947', 'video_948', 'video_949', 'video_950', 'video_951', 'video_952', 'video_953', 'video_954', 'video_955', 'video_956', 'video_957', 'video_958', 'video_959', 'video_960', 'video_961', 'video_962', 'video_963', 'video_964', 'video_965', 'video_966', 'video_967', 'video_968', 'video_969', 'video_970', 'video_971', 'video_972', 'video_973', 'video_974', 'video_975', 'video_976', 'video_977', 'video_978', 'video_979', 'video_980', 'video_981', 'video_982', 'video_983', 'video_984', 'video_985', 'video_986', 'video_987', 'video_988', 'video_989', 'video_990', 'video_991', 'video_992', 'video_993', 'video_994', 'video_995', 'video_996', 'video_997', 'video_998', 'video_999', 'video_1000', 'video_1001', 'video_1002', 'video_1003', 'video_1004', 'video_1005', 'video_1006', 'video_1007', 'video_1008', 'video_1009', 'video_1010', 'video_1011', 'video_1012', 'video_1013', 'video_1014', 'video_1015', 'video_1016', 'video_1017', 'video_1018', 'video_1019', 'video_1020', 'video_1021', 'video_1022', 'video_1023', 'video_1024', 'video_1025', 'video_1026', 'video_1027', 'video_1028', 'video_1029', 'video_1030', 'video_1031', 'video_1032', 'video_1033', 'video_1034', 'video_1035', 'video_1036', 'video_1037', 'video_1038', 'video_1039', 'video_1040', 'video_1041', 'video_1042', 'video_1043', 'video_1044', 'video_1045', 'video_1046', 'video_1047', 'video_1048', 'video_1049', 'video_1050', 'video_1051', 'video_1052', 'video_1053', 'video_1054', 'video_1055', 'video_1056', 'video_1057', 'video_1058', 'video_1059', 'video_1060', 'video_1061', 'video_1062', 'video_1063', 'video_1064', 'video_1065', 'video_1066', 'video_1067', 'video_1068', 'video_1069', 'video_1070', 'video_1071', 'video_1072', 'video_1073', 'video_1074', 'video_1075', 'video_1076', 'video_1077', 'video_1078', 'video_1079', 'video_1080', 'video_1081', 'video_1082', 'video_1083', 'video_1084', 'video_1085', 'video_1086', 'video_1087', 'video_1088', 'video_1089' ...
# Checking /content/drive/MyDrive/MyDataset/rash ...
# Videos inside 'rash': ['video_244', 'video_245', 'video_246', 'video_247', 'video_248', 'video_249', 'video_250', 'video_251', 'video_252', 'video_253', 'video_254', 'video_255', 'video_256', 'video_257', 'video_258', 'video_259', 'video_260', 'video_261', 'video_262', 'video_263', 'video_264', 'video_265', 'video_266', 'video_267', 'video_268', 'video_269', 'video_270', 'video_271', 'video_272', 'video_273', 'video_274', 'video_275', 'video_276', 'video_277', 'video_278', 'video_279', 'video_280', 'video_281', 'video_282', 'video_283', 'video_284', 'video_285', 'video_286', 'video_287', 'video_288', 'video_289', 'video_290', 'video_291', 'video_292', 'video_293', 'video_294', 'video_295', 'video_296', 'video_297', 'video_298', 'video_299', 'video_300', 'video_301', 'video_302', 'video_303', 'video_304', 'video_305', 'video_306', 'video_307', 'video_308', 'video_309', 'video_310', 'video_311', 'video_312', 'video_313', 'video_314', 'video_315', 'video_316', 'video_317', 'video_318', 'video_319', 'video_320', 'video_321', 'video_322', 'video_323', 'video_324', 'video_325', 'video_326', 'video_327', 'video_328', 'video_329', 'video_330', 'video_331', 'video_332', 'video_333', 'video_334', 'video_335', 'video_336', 'video_337', 'video_338', 'video_339', 'video_340', 'video_341', 'video_342', 'video_343', 'video_344', 'video_345', 'video_346', 'video_347', 'video_348', 'video_349', 'video_350', 'video_351', 'video_352', 'video_353', 'video_354', 'video_355', 'video_356', 'video_357', 'video_358', 'video_359', 'video_360', 'video_361', 'video_362', 'video_363', 'video_364', 'video_365', 'video_366', 'video_367', 'video_368', 'video_369', 'video_370', 'video_371', 'video_372', 'video_373', 'video_374', 'video_375', 'video_376', 'video_377', 'video_378', 'video_379', 'video_380', 'video_381', 'video_382', 'video_383', 'video_384', 'video_385', 'video_386', 'video_387', 'video_388', 'video_389', 'video_390', 'video_391', 'video_392', 'video_393', 'video_394', 'video_395', 'video_396', 'video_397', 'video_398', 'video_399', 'video_400', 'video_401', 'video_402', 'video_403', 'video_404', 'video_405', 'video_406', 'video_407', 'video_408', 'video_409', 'video_410', 'video_411', 'video_412', 'video_413', 'video_414', 'video_415', 'video_416', 'video_417', 'video_418', 'video_419', 'video_420', 'video_421', 'video_422', 'video_423', 'video_424', 'video_425', 'video_426', 'video_427', 'video_428', 'video_429', 'video_431', 'video_430', 'video_432', 'video_433', 'video_434', 'video_435', 'video_436', 'video_437', 'video_438', 'video_439', 'video_440', 'video_441', 'video_442', 'video_443', 'video_444', 'video_445', 'video_446', 'video_447', 'video_448', 'video_449', 'video_450', 'video_451', 'video_452', 'video_453', 'video_454', 'video_455', 'video_456', 'video_457', 'video_458', 'video_459', 'video_460', 'video_461', 'video_462', 'video_463', 'video_464', 'video_465', 'video_466', 'video_467', 'video_468', 'video_469', 'video_470', 'video_471', 'video_472', 'video_473', 'video_474', 'video_475', 'video_476', 'video_477', 'video_478', 'video_479', 'video_480', 'video_481', 'video_482', 'video_483', 'video_484', 'video_485', 'video_486', 'video_487', 'video_488', 'video_489', 'video_490', 'video_491', 'video_492', 'video_493', 'video_494', 'video_495', 'video_496', 'video_497', 'video_498', 'video_499', 'video_500', 'video_501', 'video_502', 'video_503', 'video_504', 'video_505', 'video_506', 'video_507', 'video_508', 'video_509', 'video_510', 'video_511', 'video_512', 'video_513', 'video_514', 'video_515', 'video_516', 'video_517', 'video_518', 'video_519', 'video_520', 'video_521', 'video_522', 'video_523', 'video_524', 'video_525', 'video_526', 'video_527', 'video_528', 'video_529', 'video_530', 'video_531', 'video_533', 'video_532', 'video_534', 'video_535', 'video_536', 'video_537', 'video_538', 'video_540', 'video_539', 'video_541', 'video_542', 'video_543', 'video_544', 'video_545', 'video_546', 'video_547', 'video_548', 'video_549', ...

# %%
import os
from PIL import Image

# Set the path to your dataset folder
DATASET_PATH = "/content/drive/MyDrive/MyDataset"

def is_valid_image(image_path):
    """Check if an image is valid and can be opened."""
    try:
        with Image.open(image_path) as img:
            img.verify()  # Verify image integrity
        return True
    except Exception:
        return False

def repair_image(image_path):
    """Try to repair an image by re-saving it."""
    try:
        with Image.open(image_path) as img:
            img = img.convert("RGB")  # Convert to a valid format
            img.save(image_path)  # Overwrite the existing file
        print(f"Repaired: {image_path}")
        return True
    except Exception:
        return False

def clean_dataset():
    """Scan and attempt to repair images in the dataset."""
    corrupted_count = 0

    for root, _, files in os.walk(DATASET_PATH):
        for file in files:
            file_path = os.path.join(root, file)

            if not is_valid_image(file_path):
                print(f"Corrupted: {file_path}")
                if repair_image(file_path):
                    continue  # Skip to the next file if repair was successful
                else:
                    corrupted_count += 1

    print(f"Total unrepaired corrupted images: {corrupted_count}")

# Run the cleaning process
clean_dataset()
# Out:
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35296.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35297.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35298.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35299.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35300.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35301.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35302.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35303.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_1175/35304.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06887.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06888.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06889.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06890.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06891.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06892.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06893.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06894.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06895.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06896.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06897.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06898.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06899.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06900.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_229/06901.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07270.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07271.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07272.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07273.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07274.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07275.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_242/07276.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07301.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07302.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07303.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07304.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07305.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_243/07306.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09535.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09536.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09537.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09538.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09539.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09540.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09541.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09542.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09543.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09544.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09545.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09546.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09547.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09548.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_309/09549.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14201.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14202.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14203.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14204.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14205.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14206.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14207.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14208.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14209.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14210.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14211.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14212.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14213.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14214.jpg
# Corrupted: /content/drive/MyDrive/MyDataset/normal/video_473/14215.jpg
# Total unrepaired corrupted images: 67

# %%
import os
import numpy as np
import cv2
from tensorflow.keras.utils import to_categorical

# Paths
DATASET_PATH = "/content/drive/MyDrive/MyDataset"
OUTPUT_PATH = "/content/drive/MyDrive/preprocessed"
os.makedirs(OUTPUT_PATH, exist_ok=True)

# Config
CATEGORIES = ["normal", "rash"]
IMG_SIZE = (128, 128)  # Resize images to this size
SEQUENCE_LENGTH = 15   # Ensure each video has exactly this many frames

def preprocess_and_save():
    """Preprocess videos and save as .npy files."""
    for label, category in enumerate(CATEGORIES):
        category_path = os.path.join(DATASET_PATH, category)
        save_path = os.path.join(OUTPUT_PATH, category)
        os.makedirs(save_path, exist_ok=True)

        if not os.path.exists(category_path):
            print(f"❌ Error: {category_path} does not exist!")
            continue

        print(f"🔄 Processing category: {category}")

        for video_folder in os.listdir(category_path):
            video_path = os.path.join(category_path, video_folder)
            save_file = os.path.join(save_path, f"{video_folder}.npy")

            if not os.path.isdir(video_path):
                print(f"⚠️ Skipping {video_folder}, not a folder.")
                continue

            print(f"📂 Processing video: {video_folder}")
            frames = []

            # Load frames
            for img_name in sorted(os.listdir(video_path)):
                img_path = os.path.join(video_path, img_name)
                if not img_name.lower().endswith((".jpg", ".png")):
                    print(f"➡️ Skipping {img_name}, not an image file.")
                    continue

                img = cv2.imread(img_path)
                img = cv2.resize(img, IMG_SIZE) / 255.0  # Normalize
                frames.append(img)

            # Ensure uniform length
            if len(frames) < SEQUENCE_LENGTH:
                print(f"🛠️ Padding {video_folder} with black frames.")
                while len(frames) < SEQUENCE_LENGTH:
                    frames.append(np.zeros((IMG_SIZE[0], IMG_SIZE[1], 3)))  # Black frame

            frames = frames[:SEQUENCE_LENGTH]  # Trim if longer
            np.save(save_file, np.array(frames, dtype=np.float32))  # Save to disk

    print("✅ Preprocessing complete!")

# Run preprocessing
preprocess_and_save()
# Out:
# 🔄 Processing category: normal
# 📂 Processing video: video_791
# 🛠️ Padding video_791 with black frames.
# 📂 Processing video: video_792
# 📂 Processing video: video_793
# 📂 Processing video: video_794
# 📂 Processing video: video_795
# 📂 Processing video: video_796
# 📂 Processing video: video_797
# 📂 Processing video: video_798
# 🛠️ Padding video_798 with black frames.
# 📂 Processing video: video_799
# 🛠️ Padding video_799 with black frames.
# 📂 Processing video: video_800
# 🛠️ Padding video_800 with black frames.
# 📂 Processing video: video_801
# 📂 Processing video: video_802
# 📂 Processing video: video_803
# 📂 Processing video: video_804
# 📂 Processing video: video_805
# 📂 Processing video: video_806
# 📂 Processing video: video_807
# 📂 Processing video: video_808
# 📂 Processing video: video_809
# 📂 Processing video: video_810
# 📂 Processing video: video_811
# 📂 Processing video: video_812
# 📂 Processing video: video_813
# 📂 Processing video: video_814
# 📂 Processing video: video_815
# 📂 Processing video: video_816
# 📂 Processing video: video_817
# 📂 Processing video: video_818
# 📂 Processing video: video_819
# 📂 Processing video: video_820
# 📂 Processing video: video_821
# 📂 Processing video: video_822
# 📂 Processing video: video_823
# 📂 Processing video: video_824
# 📂 Processing video: video_825
# 📂 Processing video: video_826
# 📂 Processing video: video_827
# 📂 Processing video: video_828
# 📂 Processing video: video_829
# 📂 Processing video: video_830
# 📂 Processing video: video_831
# 📂 Processing video: video_832
# 🛠️ Padding video_832 with black frames.
# 📂 Processing video: video_833
# 🛠️ Padding video_833 with black frames.
# 📂 Processing video: video_834
# 📂 Processing video: video_835
# 📂 Processing video: video_836
# 📂 Processing video: video_837
# 📂 Processing video: video_838
# 📂 Processing video: video_839
# 📂 Processing video: video_840
# 📂 Processing video: video_841
# 📂 Processing video: video_842
# 📂 Processing video: video_843
# 📂 Processing video: video_844
# 📂 Processing video: video_845
# 📂 Processing video: video_846
# 🛠️ Padding video_846 with black frames.
# 📂 Processing video: video_847
# 🛠️ Padding video_847 with black frames.
# 📂 Processing video: video_848
# 📂 Processing video: video_849
# 📂 Processing video: video_850
# 📂 Processing video: video_851
# 📂 Processing video: video_852
# 📂 Processing video: video_853
# 📂 Processing video: video_854
# 📂 Processing video: video_855
# 📂 Processing video: video_856
# 📂 Processing video: video_857
# 📂 Processing video: video_858
# 🛠️ Padding video_858 with black frames.
# 📂 Processing video: video_859
# 📂 Processing video: video_860
# 📂 Processing video: video_861
# 📂 Processing video: video_862
# 📂 Processing video: video_863
# 📂 Processing video: video_864
# 📂 Processing video: video_865
# 📂 Processing video: video_866
# 🛠️ Padding video_866 with black frames.
# 📂 Processing video: video_867
# 📂 Processing video: video_868
# 📂 Processing video: video_869
# 📂 Processing video: video_870
# 📂 Processing video: video_871
# 📂 Processing video: video_872
# 🛠️ Padding video_872 with black frames.
# 📂 Processing video: video_873
# 🛠️ Padding video_873 with black frames.
# 📂 Processing video: video_874
# 🛠️ Padding video_874 with black frames.
# 📂 Processing video: video_875
# 📂 Processing video: video_876
# 📂 Processing video: video_877
# 📂 Processing video: video_878
# 📂 Processing video: video_879
# 📂 Processing video: video_880
# 📂 Processing video: video_881
# 📂 Processing video: video_882
# 📂 Processing video: video_883
# 📂 Processing video: video_884
# 📂 Processing video: video_885
# 📂 Processing video: video_886
# 🛠️ Padding video_886 with black frames.
# 📂 Processing video: video_887
# 📂 Processing video: video_888
# 🛠️ Padding video_888 with black frames.
# 📂 Processing video: video_889
# 🛠️ Padding video_889 with black frames.
# 📂 Processing video: video_890
# 🛠️ Padding video_890 with black frames.
# 📂 Processing video: video_891
# 📂 Processing video: video_892
# 🛠️ Padding video_892 with black frames.
# 📂 Processing video: video_893
# 🛠️ Padding video_893 with black frames.
# 📂 Processing video: video_894
# 🛠️ Padding video_894 with black frames.
# 📂 Processing video: video_895
# 🛠️ Padding video_895 with black frames.
# 📂 Processing video: video_896
# 🛠️ Padding video_896 with black frames.
# 📂 Processing video: video_897
# 🛠️ Padding video_897 with black frames.
# 📂 Processing video: video_898
# 🛠️ Padding video_898 with black frames.
# 📂 Processing video: video_899
# 🛠️ Padding video_899 with black frames.
# 📂 Processing video: video_900
# 📂 Processing video: video_901
# 📂 Processing video: video_902
# 📂 Processing video: video_903
# 📂 Processing video: video_904
# 📂 Processing video: video_905
# 📂 Processing video: video_906
# 📂 Processing video: video_907
# 📂 Processing video: video_908
# 📂 Processing video: video_909
# 📂 Processing video: video_910
# 📂 Processing video: video_911
# 📂 Processing video: video_912
# 📂 Processing video: video_913
# 📂 Processing video: video_914
# 📂 Processing video: video_915
# 📂 Processing video: video_916
# 📂 Processing video: video_917
# 📂 Processing video: video_918
# 📂 Processing video: video_919
# 📂 Processing video: video_920
# 📂 Processing video: video_921
# 🛠️ Padding video_921 with black frames.
# 📂 Processing video: video_922
# 🛠️ Padding video_922 with black frames.
# 📂 Processing video: video_923
# 📂 Processing video: video_924
# 📂 Processing video: video_925
# 📂 Processing video: video_926
# 📂 Processing video: video_927
# 📂 Processing video: video_928
# 📂 Processing video: video_929
# 📂 Processing video: video_930
# 📂 Processing video: video_931
# 📂 Processing video: video_932
# 📂 Processing video: video_933
# 📂 Processing video: video_934
# 📂 Processing video: video_935
# 📂 Processing video: video_936
# 📂 Processing video: video_937
# 📂 Processing video: video_938
# 🛠️ Padding video_938 with black frames.
# 📂 Processing video: video_939
# 🛠️ Padding video_939 with black frames.
# 📂 Processing video: video_940
# 🛠️ Padding video_940 with black frames.
# 📂 Processing video: video_941
# 🛠️ Padding video_941 with black frames.
# 📂 Processing video: video_942
# 📂 Processing video: video_943
# 📂 Processing video: video_944
# 📂 Processing video: video_945
# 📂 Processing video: video_946
# 📂 Processing video: video_947
# 📂 Processing video: video_948
# 📂 Processing video: video_949
# 📂 Processing video: video_950
# 📂 Processing video: video_951
# 📂 Processing video: video_952
# 📂 Processing video: video_953
# 📂 Processing video: video_954
# 📂 Processing video: video_955
# 📂 Processing video: video_956
# 📂 Processing video: video_957
# 📂 Processing video: video_958
# 📂 Processing video: video_959
# 📂 Processing video: video_960
# 📂 Processing video: video_961
# 🛠️ Padding video_961 with black frames.
# 📂 Processing video: video_962
# 🛠️ Padding video_962 with black frames.
# 📂 Processing video: video_963
# 📂 Processing video: video_964
# 📂 Processing video: video_965
# 🛠️ Padding video_965 with black frames.
# 📂 Processing video: video_966
# 📂 Processing video: video_967
# 📂 Processing video: video_968
# 📂 Processing video: video_969
# 📂 Processing video: video_970
# 📂 Processing video: video_971
# 🛠️ Padding video_971 with black frames.
# 📂 Processing video: video_972
# 📂 Processing video: video_973
# 📂 Processing video: video_974
# 📂 Processing video: video_975
# 📂 Processing video: video_976
# 📂 Processing video: video_977
# 📂 Processing video: video_978
# 📂 Processing video: video_979
# 🛠️ Padding video_979 with black frames.
# 📂 Processing video: video_980
# 📂 Processing video: video_981
# 📂 Processing video: video_982
# 📂 Processing video: video_983
# 📂 Processing video: video_984
# 📂 Processing video: video_985
# 📂 Processing video: video_986
# 🛠️ Padding video_986 with black frames.
# 📂 Processing video: video_987
# 📂 Processing video: video_988
# 📂 Processing video: video_989
# 📂 Processing video: video_990
# 📂 Processing video: video_991
# 🛠️ Padding video_991 with black frames.
# 📂 Processing video: video_992
# 📂 Processing video: video_993
# 📂 Processing video: video_994
# 📂 Processing video: video_995
# 🛠️ Padding video_995 with black frames.
# 📂 Processing video: video_996
# 📂 Processing video: video_997
# 📂 Processing video: video_998
# 📂 Processing video: video_999
# 📂 Processing video: video_1000
# 📂 Processing video: video_1001
# 📂 Processing video: video_1002
# 📂 Processing video: video_1003
# 📂 Processing video: video_1004
# 📂 Processing video: video_1005
# 📂 Processing video: video_1006
# 📂 Processing video: video_1007
# 📂 Processing video: video_1008
# 📂 Processing video: video_1009
# 🛠️ Padding video_1009 with black frames.
# 📂 Processing video: video_1010
# 📂 Processing video: video_1011
# 📂 Processing video: video_1012
# 📂 Processing video: video_1013
# 📂 Processing video: video_1014
# 📂 Processing video: video_1015
# 📂 Processing video: video_1016
# 📂 Processing video: video_1017
# 📂 Processing video: video_1018
# 📂 Processing video: video_1019
# 📂 Processing video: video_1020
# 📂 Processing video: video_1021
# 🛠️ Padding video_1021 with black frames.
# 📂 Processing video: video_1022
# 📂 Processing video: video_1023
# 🛠️ Padding video_1023 with black frames.
# 📂 Processing video: video_1024
# 🛠️ Padding video_1024 with black frames.
# 📂 Processing video: video_1025
# 🛠️ Padding video_1025 with black frames.
# 📂 Processing video: video_1026
# 🛠️ Padding video_1026 with black frames.
# 📂 Processing video: video_1027
# 🛠️ Padding video_1027 with black frames.
# 📂 Processing video: video_1028
# 📂 Processing video: video_1029
# 📂 Processing video: video_1030
# 📂 Processing video: video_1031
# 📂 Processing video: video_1032
# 📂 Processing video: video_1033
# 📂 Processing video: video_1034
# 🛠️ Padding video_1034 with black frames.
# 📂 Processing video: video_1035
# 🛠️ Padding video_1035 with black frames.
# 📂 Processing video: video_1036
# 🛠️ Padding video_1036 with black frames.
# 📂 Processing video: video_1037
# 🛠️ Padding video_1037 with black frames.
# 📂 Processing video: video_1038
# 🛠️ Padding video_1038 with black frames.
# 📂 Processing video: video_1039
# 🛠️ Padding video_1039 with black frames.
# 📂 Processing video: video_1040
# 🛠️ Padding video_1040 with black frames.
# 📂 Processing video: video_1041
# 🛠️ Padding video_1041 with black frames.
# 📂 Processing video: video_1042
# 🛠️ Padding video_1042 with black frames.
# 📂 Processing video: video_1043
# 🛠️ Padding video_1043 with black frames.
# 📂 Processing video: video_1044
# 🛠️ Padding video_1044 with black frames.
# 📂 Processing video: video_1045
# 🛠️ Padding video_1045 with black frames.
# 📂 Processing video: video_1046
# 🛠️ Padding video_1046 with black frames.
# 📂 Processing video: video_1047
# 🛠️ Padding video_1047 with black frames.
# 📂 Processing video: video_1048
# 🛠️ Padding video_1048 with black frames.
# 📂 Processing video: video_1049
# 📂 Processing video: video_1050
# 🛠️ Padding video_1050 with black frames.
# 📂 Processing video: video_1051
# 🛠️ Padding video_1051 with black frames.
# 📂 Processing video: video_1052
# 🛠️ Padding video_1052 with black frames.
# 📂 Processing video: video_1053
# 📂 Processing video: video_1054
# 🛠️ Padding video_1054 with black frames.
# 📂 Processing video: video_1055
# 📂 Processing video: video_1056
# 🛠️ Padding video_1056 with black frames.
# 📂 Processing video: video_1057
# 🛠️ Padding video_1057 with black frames.
# 📂 Processing video: video_1058
# 🛠️ Padding video_1058 with black frames.
# 📂 Processing video: video_1059
# 🛠️ Padding video_1059 with black frames.
# 📂 Processing video: video_1060
# 🛠️ Padding video_1060 with black frames.
# 📂 Processing video: video_1061
# 🛠️ Padding video_1061 with black frames.
# 📂 Processing video: video_1062
# 🛠️ Padding video_1062 with black frames.
# 📂 Processing video: video_1063
# 🛠️ Padding video_1063 with black frames.
# 📂 Processing video: video_1064
# 📂 Processing video: video_1065
# 📂 Processing video: video_1066
# 📂 Processing video: video_1067
# 📂 Processing video: video_1068
# 📂 Processing video: video_1069
# 📂 Processing video: video_1070
# 📂 Processing video: video_1071
# 📂 Processing video: video_1072
# 🛠️ Padding video_1072 with black frames.
# 📂 Processing video: video_1073
# 🛠️ Padding video_1073 with black frames.
# 📂 Processing video: video_1074
# 🛠️ Padding video_1074 with black frames.
# 📂 Processing video: video_1075
# 🛠️ Padding video_1075 with black frames.
# 📂 Processing video: video_1076
# 🛠️ Padding video_1076 with black frames.
# 📂 Processing video: video_1077
# 🛠️ Padding video_1077 with black frames.
# 📂 Processing video: video_1078
# 🛠️ Padding video_1078 with black frames.
# 📂 Processing video: video_1079
# 📂 Processing video: video_1080
# 📂 Processing video: video_1081
# 📂 Processing video: video_1082
# 📂 Processing video: video_1083
# 📂 Processing video: video_1084
# 📂 Processing video: video_1085
# 📂 Processing video: video_1086
# 📂 Processing video: video_1087
# 📂 Processing video: video_1088
# 📂 Processing video: video_1089
# 📂 Processing video: video_1090
# 📂 Processing video: video_1091
# 📂 Processing video: video_1092
# 📂 Processing video: video_1093
# 📂 Processing video: video_1094
# 📂 Processing video: video_1095
# 📂 Processing video: video_1096
# 📂 Processing video: video_1097
# 📂 Processing video: video_1098
# 📂 Processing video: video_1099
# 📂 Processing video: video_1100
# 📂 Processing video: video_1101
# 📂 Processing video: video_1102
# 📂 Processing video: video_1103
# 📂 Processing video: video_1104
# 📂 Processing video: video_1105
# 📂 Processing video: video_1106
# 📂 Processing video: video_1107
# 📂 Processing video: video_1108
# 📂 Processing video: video_1109
# 📂 Processing video: video_1110
# 📂 Processing video: video_1111
# 📂 Processing video: video_1112
# 📂 Processing video: video_1113
# 🛠️ Padding video_1113 with black frames.
# 📂 Processing video: video_1114
# 🛠️ Padding video_1114 with black frames.
# 📂 Processing video: video_1115
# 📂 Processing video: video_1116
# 📂 Processing video: video_1117
# 📂 Processing video: video_1118
# 📂 Processing video: video_1119
# 📂 Processing video: video_1120
# 📂 Processing video: video_1121
# 📂 Processing video: video_1122
# 📂 Processing video: video_1123
# 📂 Processing video: video_1124
# 📂 Processing video: video_1125
# 📂 Processing video: video_1126
# 📂 Processing video: video_1127
# 📂 Processing video: video_1128
# 📂 Processing video: video_1129
# 📂 Processing video: video_1130
# 📂 Processing video: video_1131
# 📂 Processing video: video_1132
# 📂 Processing video: video_1133
# 📂 Processing video: video_1134
# 📂 Processing video: video_1135
# 📂 Processing video: video_1136
# 📂 Processing video: video_1137
# 🛠️ Padding video_1137 with black frames.
# 📂 Processing video: video_1138
# 📂 Processing video: video_1139
# 📂 Processing video: video_1140
# 📂 Processing video: video_1141
# 📂 Processing video: video_1142
# 📂 Processing video: video_1143
# 📂 Processing video: video_1144
# 📂 Processing video: video_1145
# 📂 Processing video: video_1146
# 📂 Processing video: video_1147
# 🛠️ Padding video_1147 with black frames.
# 📂 Processing video: video_1148
# 📂 Processing video: video_1149
# 📂 Processing video: video_1150
# 📂 Processing video: video_1151
# 🛠️ Padding video_1151 with black frames.
# 📂 Processing video: video_1152
# 🛠️ Padding video_1152 with black frames.
# 📂 Processing video: video_1153
# 📂 Processing video: video_1154
# 📂 Processing video: video_1155
# 📂 Processing video: video_1156
# 🛠️ Padding video_1156 with black frames.
# 📂 Processing video: video_1157
# 🛠️ Padding video_1157 with black frames.
# 📂 Processing video: video_1158
# 🛠️ Padding video_1158 with black frames.
# 📂 Processing video: video_1159
# 🛠️ Padding video_1159 with black frames.
# 📂 Processing video: video_1160
# 🛠️ Padding video_1160 with black frames.
# 📂 Processing video: video_1161
# 🛠️ Padding video_1161 with black frames.
# 📂 Processing video: video_1162
# 🛠️ Padding video_1162 with black frames.
# 📂 Processing video: video_1163
# 🛠️ Padding video_1163 with black frames.
# 📂 Processing video: video_1164
# 🛠️ Padding video_1164 with black frames.
# 📂 Processing video: video_1165
# 🛠️ Padding video_1165 with black frames.
# 📂 Processing video: video_1166
# 🛠️ Padding video_1166 with black frames.
# 📂 Processing video: video_1167
# 🛠️ Padding video_1167 with black frames.
# 📂 Processing video: video_1168
# 🛠️ Padding video_1168 with black frames.
# 📂 Processing video: video_1169
# 🛠️ Padding video_1169 with black frames.
# 📂 Processing video: video_1170
# 🛠️ Padding video_1170 with black frames.
# 📂 Processing video: video_1171
# 📂 Processing video: video_1172
# 📂 Processing video: video_1173
# 📂 Processing video: video_1174
# 📂 Processing video: video_1175
# 📂 Processing video: video_1176
# 📂 Processing video: video_1177
# 📂 Processing video: video_1178
# 📂 Processing video: video_1179
# 📂 Processing video: video_1180
# 📂 Processing video: video_1181
# 📂 Processing video: video_1182
# 📂 Processing video: video_1183
# 📂 Processing video: video_1184
# 📂 Processing video: video_1185
# 📂 Processing video: video_1186
# 📂 Processing video: video_1187
# 📂 Processing video: video_1188
# 📂 Processing video: video_1189
# 🛠️ Padding video_1189 with black frames.
# 📂 Processing video: video_1190
# 📂 Processing video: video_1191
# 📂 Processing video: video_1192
# 📂 Processing video: video_1193
# 📂 Processing video: video_1194
# 📂 Processing video: video_1195
# 📂 Processing video: video_1196
# 🛠️ Padding video_1196 with black frames.
# 📂 Processing video: video_1197
# 🛠️ Padding video_1197 with black frames.
# 📂 Processing video: video_1198
# 🛠️ Padding video_1198 with black frames.
# 📂 Processing video: video_1199
# 🛠️ Padding video_1199 with black frames.
# 📂 Processing video: video_1200
# 🛠️ Padding video_1200 with black frames.
# 📂 Processing video: video_1201
# 🛠️ Padding video_1201 with black frames.
# 📂 Processing video: video_1202
# 🛠️ Padding video_1202 with black frames.
# 📂 Processing video: video_1203
# 🛠️ Padding video_1203 with black frames.
# 📂 Processing video: video_1204
# 📂 Processing video: video_1205
# 📂 Processing video: video_1206
# 📂 Processing video: video_1207
# 📂 Processing video: video_1208
# 📂 Processing video: video_1209
# 📂 Processing video: video_1210
# 📂 Processing video: video_1211
# 📂 Processing video: video_1212
# 📂 Processing video: video_1213
# 📂 Processing video: video_1214
# 📂 Processing video: video_1215
# 📂 Processing video: video_1216
# 📂 Processing video: video_1217
# 📂 Processing video: video_1218
# 📂 Processing video: video_1219
# 📂 Processing video: video_1220
# 📂 Processing video: video_1221
# 🛠️ Padding video_1221 with black frames.
# 📂 Processing video: video_1222
# 📂 Processing video: video_1223
# 📂 Processing video: video_1224
# 📂 Processing video: video_1225
# 📂 Processing video: video_1226
# 📂 Processing video: video_1227
# 📂 Processing video: video_1228
# 📂 Processing video: video_1229
# 📂 Processing video: video_1230
# 📂 Processing video: video_1231
# 📂 Processing video: video_1232
# 📂 Processing video: video_1233
# 📂 Processing video: video_1234
# 📂 Processing video: video_1235
# 📂 Processing video: video_1236
# 📂 Processing video: video_1237
# 📂 Processing video: video_1238
# 📂 Processing video: video_1239
# 📂 Processing video: video_1240
# 📂 Processing video: video_1241
# 📂 Processing video: video_1242
# 📂 Processing video: video_1243
# 📂 Processing video: video_1244
# 📂 Processing video: video_1245
# 📂 Processing video: video_1246
# 📂 Processing video: video_1247
# 📂 Processing video: video_1248
# 📂 Processing video: video_1249
# 📂 Processing video: video_1250
# 📂 Processing video: video_1251
# 📂 Processing video: video_1252
# 📂 Processing video: video_1253
# 📂 Processing video: video_1254
# 📂 Processing video: video_1255
# 📂 Processing video: video_1256
# 📂 Processing video: video_1257
# 📂 Processing video: video_1258
# 📂 Processing video: video_1259
# 📂 Processing video: video_1260
# 📂 Processing video: video_1261
# 📂 Processing video: video_1262
# 📂 Processing video: video_1263
# 📂 Processing video: video_1264
# 📂 Processing video: video_1265
# 📂 Processing video: video_1266
# 📂 Processing video: video_1267
# 📂 Processing video: video_1268
# 📂 Processing video: video_1269
# 📂 Processing video: video_1270
# 🛠️ Padding video_1270 with black frames.
# 📂 Processing video: video_1271
# 🛠️ Padding video_1271 with black frames.
# 📂 Processing video: video_1272
# 📂 Processing video: video_1273
# 📂 Processing video: video_1274
# 📂 Processing video: video_1275
# 📂 Processing video: video_1276
# 📂 Processing video: video_1277
# 📂 Processing video: video_1278
# 📂 Processing video: video_1279
# 📂 Processing video: video_1280
# 📂 Processing video: video_1281
# 📂 Processing video: video_1282
# 📂 Processing video: video_1283
# 📂 Processing video: video_1284
# 📂 Processing video: video_1285
# 📂 Processing video: video_1286
# 📂 Processing video: video_1287
# 📂 Processing video: video_1288
# 📂 Processing video: video_1289
# 📂 Processing video: video_1290
# 📂 Processing video: video_1291
# 📂 Processing video: video_1292
# 📂 Processing video: video_1293
# 📂 Processing video: video_1294
# 📂 Processing video: video_1295
# 📂 Processing video: video_1296
# 📂 Processing video: video_1297
# 📂 Processing video: video_1298
# 📂 Processing video: video_1299
# 📂 Processing video: video_1300
# 📂 Processing video: video_1301
# 📂 Processing video: video_1302
# 📂 Processing video: video_1303
# 📂 Processing video: video_1304
# 📂 Processing video: video_1305
# 📂 Processing video: video_1306
# 📂 Processing video: video_1307
# 📂 Processing video: video_1308
# 📂 Processing video: video_1309
# 📂 Processing video: video_1310
# 📂 Processing video: video_1311
# 📂 Processing video: video_1312
# 📂 Processing video: video_1313
# 📂 Processing video: video_1314
# 📂 Processing video: video_1315
# 📂 Processing video: video_1316
# 📂 Processing video: video_1317
# 📂 Processing video: video_1318
# 📂 Processing video: video_1319
# 📂 Processing video: video_1320
# 🛠️ Padding video_1320 with black frames.
# 📂 Processing video: video_1321
# 🛠️ Padding video_1321 with black frames.
# 📂 Processing video: video_1322
# 🛠️ Padding video_1322 with black frames.
# 📂 Processing video: video_1323
# 🛠️ Padding video_1323 with black frames.
# 📂 Processing video: video_1324
# 🛠️ Padding video_1324 with black frames.
# 📂 Processing video: video_1325
# 🛠️ Padding video_1325 with black frames.
# 📂 Processing video: video_1326
# 🛠️ Padding video_1326 with black frames.
# 📂 Processing video: video_1327
# 🛠️ Padding video_1327 with black frames.
# 📂 Processing video: video_1328
# 🛠️ Padding video_1328 with black frames.
# 📂 Processing video: video_1329
# 🛠️ Padding video_1329 with black frames.
# 📂 Processing video: video_1330
# 🛠️ Padding video_1330 with black frames.
# 📂 Processing video: video_1331
# 🛠️ Padding video_1331 with black frames.
# 📂 Processing video: video_1332
# 🛠️ Padding video_1332 with black frames.
# 📂 Processing video: video_1333
# 🛠️ Padding video_1333 with black frames.
# 📂 Processing video: video_1334
# 📂 Processing video: video_1335
# 📂 Processing video: video_1336
# 📂 Processing video: video_1337
# 📂 Processing video: video_1338
# 📂 Processing video: video_1339
# 📂 Processing video: video_1340
# 📂 Processing video: video_1341
# 📂 Processing video: video_1342
# 📂 Processing video: video_1343
# 📂 Processing video: video_1344
# 🛠️ Padding video_1344 with black frames.
# 📂 Processing video: video_1345
# 📂 Processing video: video_1346
# 📂 Processing video: video_1347
# 📂 Processing video: video_1348
# 📂 Processing video: video_1349
# 📂 Processing video: video_1350
# 📂 Processing video: video_1351
# 📂 Processing video: video_1352
# 📂 Processing video: video_1353
# 📂 Processing video: video_1354
# 📂 Processing video: video_1355
# 📂 Processing video: video_1356
# 📂 Processing video: video_1357
# 📂 Processing video: video_1358
# 📂 Processing video: video_1359
# 📂 Processing video: video_1360
# 📂 Processing video: video_1361
# 📂 Processing video: video_1362
# 🛠️ Padding video_1362 with black frames.
# 📂 Processing video: video_1363
# 🛠️ Padding video_1363 with black frames.
# 📂 Processing video: video_1364
# 📂 Processing video: video_1365
# 📂 Processing video: video_1366
# 📂 Processing video: video_1367
# 📂 Processing video: video_1368
# 📂 Processing video: video_1369
# 📂 Processing video: video_1370
# 📂 Processing video: video_1371
# 📂 Processing video: video_1372
# 📂 Processing video: video_1373
# 📂 Processing video: video_1374
# 📂 Processing video: video_1375
# 📂 Processing video: video_1376
# 📂 Processing video: video_1377
# 📂 Processing video: video_1378
# 📂 Processing video: video_1379
# 📂 Processing video: video_1380
# 📂 Processing video: video_1381
# 📂 Processing video: video_1382
# 📂 Processing video: video_1383
# 📂 Processing video: video_1384
# 📂 Processing video: video_1385
# 📂 Processing video: video_1386
# 📂 Processing video: video_1387
# 📂 Processing video: video_1388
# 🛠️ Padding video_1388 with black frames.
# 📂 Processing video: video_1389
# 🛠️ Padding video_1389 with black frames.
# 📂 Processing video: video_1390
# 📂 Processing video: video_1391
# 📂 Processing video: video_1392
# 🛠️ Padding video_1392 with black frames.
# 📂 Processing video: video_1393
# 🛠️ Padding video_1393 with black frames.
# 📂 Processing video: video_1394
# 📂 Processing video: video_1395
# 📂 Processing video: video_1396
# 📂 Processing video: video_1397
# 📂 Processing video: video_1398
# 📂 Processing video: video_1399
# 🛠️ Padding video_1399 with black frames.
# 📂 Processing video: video_1400
# 📂 Processing video: video_1401
# 📂 Processing video: video_1402
# 🛠️ Padding video_1402 with black frames.
# 📂 Processing video: video_1403
# 📂 Processing video: video_1404
# 📂 Processing video: video_1405
# 📂 Processing video: video_1406
# 📂 Processing video: video_1407
# 📂 Processing video: video_1408
# 📂 Processing video: video_1409
# 📂 Processing video: video_1410
# 📂 Processing video: video_1411
# 📂 Processing video: video_1412
# 📂 Processing video: video_1413
# 📂 Processing video: video_1414
# 📂 Processing video: video_1415
# 📂 Processing video: video_1416
# 📂 Processing video: video_1417
# 📂 Processing video: video_1418
# 📂 Processing video: video_1419
# 📂 Processing video: video_1420
# 📂 Processing video: video_1421
# 📂 Processing video: video_1422
# 📂 Processing video: video_1423
# 📂 Processing video: video_1424
# 📂 Processing video: video_1425
# 📂 Processing video: video_1426
# 📂 Processing video: video_1427
# 📂 Processing video: video_1428
# 📂 Processing video: video_1429
# 📂 Processing video: video_1430
# 📂 Processing video: video_1431
# 🛠️ Padding video_1431 with black frames.
# 📂 Processing video: video_1432
# 📂 Processing video: video_1433
# 📂 Processing video: video_1434
# 📂 Processing video: video_1435
# 📂 Processing video: video_1436
# 📂 Processing video: video_1437
# 📂 Processing video: video_1438
# 📂 Processing video: video_1439
# 📂 Processing video: video_1440
# 📂 Processing video: video_1441
# 📂 Processing video: video_1442
# 📂 Processing video: video_1443
# 📂 Processing video: video_1444
# 📂 Processing video: video_1445
# 🛠️ Padding video_1445 with black frames.
# 📂 Processing video: video_1446
# 📂 Processing video: video_1447
# 📂 Processing video: video_1448
# 📂 Processing video: video_1449
# 📂 Processing video: video_1450
# 📂 Processing video: video_1451
# 📂 Processing video: video_1452
# 📂 Processing video: video_1453
# 📂 Processing video: video_1454
# 📂 Processing video: video_1455
# 📂 Processing video: video_1456
# 📂 Processing video: video_1457
# 📂 Processing video: video_1458
# 📂 Processing video: video_1459
# 📂 Processing video: video_1460
# 📂 Processing video: video_1461
# 📂 Processing video: video_1462
# 📂 Processing video: video_1463
# 📂 Processing video: video_1464
# 📂 Processing video: video_1465
# 🛠️ Padding video_1465 with black frames.
# 📂 Processing video: video_1466
# 📂 Processing video: video_1467
# 📂 Processing video: video_1468
# 📂 Processing video: video_1469
# 📂 Processing video: video_1470
# 📂 Processing video: video_1471
# 🛠️ Padding video_1471 with black frames.
# 📂 Processing video: video_1472
# 📂 Processing video: video_1473
# 📂 Processing video: video_1474
# 📂 Processing video: video_1475
# 📂 Processing video: video_1476
# 📂 Processing video: video_1477
# 📂 Processing video: video_1478
# 📂 Processing video: video_1479
# 📂 Processing video: video_1480
# 📂 Processing video: video_1481
# 📂 Processing video: video_1482
# 📂 Processing video: video_1483
# 📂 Processing video: video_1484
# 📂 Processing video: video_1485
# 📂 Processing video: video_1486
# 📂 Processing video: video_1487
# 📂 Processing video: video_1488
# 📂 Processing video: video_1489
# 📂 Processing video: video_1490
# 📂 Processing video: video_1491
# 📂 Processing video: video_1492
# 📂 Processing video: video_1493
# 📂 Processing video: video_1494
# 📂 Processing video: video_1495
# 📂 Processing video: video_1496
# 📂 Processing video: video_1497
# 🛠️ Padding video_1497 with black frames.
# 📂 Processing video: video_1498
# 🛠️ Padding video_1498 with black frames.
# 📂 Processing video: video_1499
# 📂 Processing video: video_1500
# 🛠️ Padding video_1500 with black frames.
# 📂 Processing video: video_1501
# 🛠️ Padding video_1501 with black frames.
# 📂 Processing video: video_1502
# 🛠️ Padding video_1502 with black frames.
# 📂 Processing video: video_1503
# 🛠️ Padding video_1503 with black frames.
# 📂 Processing video: video_1504
# 📂 Processing video: video_1505
# 📂 Processing video: video_1506
# 📂 Processing video: video_1507
# 📂 Processing video: video_1508
# 📂 Processing video: video_1509
# 📂 Processing video: video_1510
# 📂 Processing video: video_1511
# 🛠️ Padding video_1511 with black frames.
# 📂 Processing video: video_1512
# 🛠️ Padding video_1512 with black frames.
# 📂 Processing video: video_1513
# 🛠️ Padding video_1513 with black frames.
# 📂 Processing video: video_1514
# 📂 Processing video: video_1515
# 📂 Processing video: video_1516
# 📂 Processing video: video_1517
# 📂 Processing video: video_1518
# 🛠️ Padding video_1518 with black frames.
# 📂 Processing video: video_1519
# 🛠️ Padding video_1519 with black frames.
# 📂 Processing video: video_1520
# 🛠️ Padding video_1520 with black frames.
# 📂 Processing video: video_1521
# 🛠️ Padding video_1521 with black frames.
# 📂 Processing video: video_1522
# 📂 Processing video: video_1523
# 🛠️ Padding video_1523 with black frames.
# 📂 Processing video: video_1524
# 🛠️ Padding video_1524 with black frames.
# 📂 Processing video: video_1525
# 🛠️ Padding video_1525 with black frames.
# 📂 Processing video: video_1526
# 🛠️ Padding video_1526 with black frames.
# 📂 Processing video: video_1527
# 🛠️ Padding video_1527 with black frames.
# 📂 Processing video: video_1528
# 🛠️ Padding video_1528 with black frames.
# 📂 Processing video: video_1529
# 🛠️ Padding video_1529 with black frames.
# 📂 Processing video: video_1530
# 🛠️ Padding video_1530 with black frames.
# 📂 Processing video: video_1531
# 🛠️ Padding video_1531 with black frames.
# 📂 Processing video: video_1532
# 🛠️ Padding video_1532 with black frames.
# 📂 Processing video: video_1533
# 📂 Processing video: video_1534
# 📂 Processing video: video_1535
# 📂 Processing video: video_1536
# 📂 Processing video: video_1537
# 📂 Processing video: video_1538
# 📂 Processing video: video_1539
# 📂 Processing video: video_1540
# 📂 Processing video: video_1541
# 📂 Processing video: video_1542
# 📂 Processing video: video_1543
# 📂 Processing video: video_1544
# 📂 Processing video: video_1545
# 📂 Processing video: video_1546
# 📂 Processing video: video_1547
# 📂 Processing video: video_1548
# 📂 Processing video: video_1549
# 📂 Processing video: video_1550
# 📂 Processing video: video_1551
# 📂 Processing video: video_1552
# 📂 Processing video: video_1553
# 📂 Processing video: video_1554
# 📂 Processing video: video_1555
# 📂 Processing video: video_1556
# 📂 Processing video: video_1557
# 📂 Processing video: video_1558
# 📂 Processing video: video_1559
# 📂 Processing video: video_1560
# 📂 Processing video: video_1561
# 📂 Processing video: video_1562
# 📂 Processing video: video_1563
# 📂 Processing video: video_1564
# 📂 Processing video: video_1565
# 📂 Processing video: video_1566
# 📂 Processing video: video_1567
# 📂 Processing video: video_1568
# 📂 Processing video: video_1569
# 📂 Processing video: video_1570
# 📂 Processing video: video_1571
# 📂 Processing video: video_1572
# 📂 Processing video: video_1573
# 📂 Processing video: video_1574
# 📂 Processing video: video_1575
# 📂 Processing video: video_1576
# 📂 Processing video: video_1577
# 📂 Processing video: video_1578
# 📂 Processing video: video_1579
# 📂 Processing video: video_1580
# 📂 Processing video: video_1581
# 📂 Processing video: video_1582
# 🛠️ Padding video_1582 with black frames.
# 📂 Processing video: video_1583
# 🛠️ Padding video_1583 with black frames.
# 📂 Processing video: video_1584
# 📂 Processing video: video_1585
# 📂 Processing video: video_1586
# 📂 Processing video: video_1587
# 📂 Processing video: video_1588
# 📂 Processing video: video_1589
# 📂 Processing video: video_1590
# 📂 Processing video: video_1591
# 📂 Processing video: video_1592
# 📂 Processing video: video_1593
# 📂 Processing video: video_1594
# 📂 Processing video: video_1595
# 📂 Processing video: video_1596
# 📂 Processing video: video_1597
# 📂 Processing video: video_1598
# 📂 Processing video: video_1599
# 📂 Processing video: video_1600
# 📂 Processing video: video_1601
# 📂 Processing video: video_1602
# 📂 Processing video: video_1603
# 📂 Processing video: video_1604
# 📂 Processing video: video_1605
# 📂 Processing video: video_1606
# 📂 Processing video: video_1607
# 📂 Processing video: video_1608
# 📂 Processing video: video_1609
# 📂 Processing video: video_1610
# 📂 Processing video: video_1611
# 📂 Processing video: video_1612
# 📂 Processing video: video_1613
# 📂 Processing video: video_1614
# 📂 Processing video: video_1615
# 📂 Processing video: video_1616
# 📂 Processing video: video_1617
# 📂 Processing video: video_1618
# 📂 Processing video: video_1619
# 📂 Processing video: video_1620
# 🛠️ Padding video_1620 with black frames.
# 📂 Processing video: video_1621
# 🛠️ Padding video_1621 with black frames.
# 📂 Processing video: video_1622
# 📂 Processing video: video_1623
# 📂 Processing video: video_1624
# 📂 Processing video: video_1625
# 📂 Processing video: video_1626
# 📂 Processing video: video_1627
# 📂 Processing video: video_1628
# 📂 Processing video: video_1629
# 📂 Processing video: video_1630
# 📂 Processing video: video_1631
# 📂 Processing video: video_1632
# 📂 Processing video: video_1633
# 📂 Processing video: video_1634
# 📂 Processing video: video_1635
# 📂 Processing video: video_1636
# 📂 Processing video: video_1637
# 📂 Processing video: video_1638
# 📂 Processing video: video_1639
# 📂 Processing video: video_1640
# 📂 Processing video: video_1641
# 📂 Processing video: video_1642
# 📂 Processing video: video_1643
# 📂 Processing video: video_1644
# 📂 Processing video: video_1645
# 📂 Processing video: video_1646
# 📂 Processing video: video_1647
# 📂 Processing video: video_1648
# 📂 Processing video: video_1649
# 📂 Processing video: video_1650
# 📂 Processing video: video_1651
# 📂 Processing video: video_1652
# 📂 Processing video: video_1653
# 📂 Processing video: video_1654
# 📂 Processing video: video_1655
# 📂 Processing video: video_1656
# 📂 Processing video: video_1657
# 📂 Processing video: video_1658
# 📂 Processing video: video_1659
# 📂 Processing video: video_1660
# 📂 Processing video: video_1661
# 📂 Processing video: video_1662
# 📂 Processing video: video_1663
# 📂 Processing video: video_1664
# 📂 Processing video: video_1665
# 📂 Processing video: video_1666
# 📂 Processing video: video_1667
# 📂 Processing video: video_1668
# 📂 Processing video: video_1669
# 📂 Processing video: video_1670
# 📂 Processing video: video_1671
# 📂 Processing video: video_1672
# 📂 Processing video: video_1673
# 📂 Processing video: video_1674
# 📂 Processing video: video_1675
# 📂 Processing video: video_1676
# 📂 Processing video: video_1677
# 📂 Processing video: video_1678
# 📂 Processing video: video_1679
# 📂 Processing video: video_1680
# 📂 Processing video: video_1681
# 📂 Processing video: video_1682
# 📂 Processing video: video_1683
# 📂 Processing video: video_1684
# 📂 Processing video: video_1685
# 📂 Processing video: video_1686
# 📂 Processing video: video_1687
# 📂 Processing video: video_1688
# 📂 Processing video: video_1689
# 📂 Processing video: video_1690
# 📂 Processing video: video_1691
# 📂 Processing video: video_1692
# 📂 Processing video: video_1693
# 📂 Processing video: video_1694
# 📂 Processing video: video_1695
# 📂 Processing video: video_1696
# 📂 Processing video: video_1697
# 📂 Processing video: video_1698
# 📂 Processing video: video_1699
# 📂 Processing video: video_1700
# 📂 Processing video: video_1701
# 📂 Processing video: video_1702
# 📂 Processing video: video_1703
# 📂 Processing video: video_1704
# 📂 Processing video: video_1705
# 📂 Processing video: video_1706
# 📂 Processing video: video_1707
# 📂 Processing video: video_1708
# 📂 Processing video: video_1709
# 📂 Processing video: video_1710
# 📂 Processing video: video_1711
# 📂 Processing video: video_1712
# 📂 Processing video: video_1713
# 📂 Processing video: video_1714
# 📂 Processing video: video_1715
# 📂 Processing video: video_1716
# 📂 Processing video: video_1717
# 📂 Processing video: video_1718
# 📂 Processing video: video_1719
# 📂 Processing video: video_1720
# 📂 Processing video: video_1721
# 📂 Processing video: video_1722
# 📂 Processing video: video_1723
# 📂 Processing video: video_1724
# 📂 Processing video: video_1725
# 📂 Processing video: video_1726
# 📂 Processing video: video_1727
# 📂 Processing video: video_1728
# 📂 Processing video: video_1729
# 📂 Processing video: video_1730
# 📂 Processing video: video_1731
# 📂 Processing video: video_1732
# 📂 Processing video: video_1733
# 📂 Processing video: video_1734
# 📂 Processing video: video_1735
# 📂 Processing video: video_1736
# 📂 Processing video: video_1737
# 📂 Processing video: video_1738
# 📂 Processing video: video_1739
# 📂 Processing video: video_1740
# 📂 Processing video: video_1741
# 📂 Processing video: video_1742
# 📂 Processing video: video_1743
# 📂 Processing video: video_1744
# 📂 Processing video: video_1745
# 📂 Processing video: video_1746
# 📂 Processing video: video_1747
# 📂 Processing video: video_1748
# 📂 Processing video: video_1749
# 📂 Processing video: video_1750
# 📂 Processing video: video_1751
# 📂 Processing video: video_1752
# 📂 Processing video: video_1753
# 📂 Processing video: video_1754
# 📂 Processing video: video_1755
# 📂 Processing video: video_1756
# 📂 Processing video: video_1757
# 📂 Processing video: video_1758
# 📂 Processing video: video_1759
# 📂 Processing video: video_1760
# 📂 Processing video: video_1761
# 📂 Processing video: video_1762
# 📂 Processing video: video_1763
# 📂 Processing video: video_1764
# 📂 Processing video: video_1765
# 🛠️ Padding video_1765 with black frames.
# 📂 Processing video: video_1766
# 🛠️ Padding video_1766 with black frames.
# 📂 Processing video: video_1767
# 🛠️ Padding video_1767 with black frames.
# 📂 Processing video: video_1768
# 🛠️ Padding video_1768 with black frames.
# 📂 Processing video: video_1769
# 🛠️ Padding video_1769 with black frames.
# 📂 Processing video: video_1770
# 🛠️ Padding video_1770 with black frames.
# 📂 Processing video: video_1771
# 🛠️ Padding video_1771 with black frames.
# 📂 Processing video: video_1772
# 📂 Processing video: video_1773
# 📂 Processing video: video_1774
# 📂 Processing video: video_1775
# 📂 Processing video: video_1776
# 📂 Processing video: video_1777
# 📂 Processing video: video_1778
# 📂 Processing video: video_1779
# 📂 Processing video: video_1780
# 📂 Processing video: video_1781
# 📂 Processing video: video_1782
# 📂 Processing video: video_1783
# 📂 Processing video: video_1784
# 📂 Processing video: video_1785
# 📂 Processing video: video_1786
# 📂 Processing video: video_1787
# 📂 Processing video: video_1788
# 📂 Processing video: video_1789
# 📂 Processing video: video_1790
# 📂 Processing video: video_001
# 📂 Processing video: video_002
# 📂 Processing video: video_003
# 📂 Processing video: video_004
# 📂 Processing video: video_005
# 📂 Processing video: video_006
# 📂 Processing video: video_007
# 📂 Processing video: video_008
# 📂 Processing video: video_009
# 📂 Processing video: video_010
# 📂 Processing video: video_011
# 📂 Processing video: video_012
# 📂 Processing video: video_013
# 📂 Processing video: video_014
# 📂 Processing video: video_015
# 📂 Processing video: video_016
# 📂 Processing video: video_017
# 📂 Processing video: video_018
# 🛠️ Padding video_018 with black frames.
# 📂 Processing video: video_019
# 📂 Processing video: video_020
# 📂 Processing video: video_021
# 🛠️ Padding video_021 with black frames.
# 📂 Processing video: video_022
# 📂 Processing video: video_023
# 📂 Processing video: video_024
# 📂 Processing video: video_025
# 📂 Processing video: video_026
# 📂 Processing video: video_027
# 📂 Processing video: video_028
# 📂 Processing video: video_029
# 📂 Processing video: video_030
# 📂 Processing video: video_031
# 📂 Processing video: video_032
# 📂 Processing video: video_033
# 📂 Processing video: video_034
# 📂 Processing video: video_035
# 📂 Processing video: video_036
# 📂 Processing video: video_037
# 📂 Processing video: video_038
# 📂 Processing video: video_039
# 📂 Processing video: video_040
# 📂 Processing video: video_041
# 📂 Processing video: video_042
# 📂 Processing video: video_043
# 📂 Processing video: video_044
# 📂 Processing video: video_045
# 📂 Processing video: video_046
# 📂 Processing video: video_047
# 📂 Processing video: video_048
# 📂 Processing video: video_049
# 📂 Processing video: video_050
# 📂 Processing video: video_051
# 🛠️ Padding video_051 with black frames.
# 📂 Processing video: video_052
# 🛠️ Padding video_052 with black frames.
# 📂 Processing video: video_053
# 📂 Processing video: video_054
# 📂 Processing video: video_055
# 📂 Processing video: video_056
# 📂 Processing video: video_057
# 📂 Processing video: video_058
# 📂 Processing video: video_059
# 📂 Processing video: video_060
# 📂 Processing video: video_061
# 📂 Processing video: video_062
# 📂 Processing video: video_063
# 📂 Processing video: video_064
# 📂 Processing video: video_065
# 📂 Processing video: video_066
# 📂 Processing video: video_067
# 📂 Processing video: video_068
# 📂 Processing video: video_069
# 📂 Processing video: video_070
# 📂 Processing video: video_071
# 📂 Processing video: video_072
# 📂 Processing video: video_073
# 📂 Processing video: video_074
# 📂 Processing video: video_075
# 📂 Processing video: video_076
# 📂 Processing video: video_077
# 📂 Processing video: video_078
# 📂 Processing video: video_079
# 📂 Processing video: video_080
# 🛠️ Padding video_080 with black frames.
# 📂 Processing video: video_081
# 📂 Processing video: video_082
# 📂 Processing video: video_083
# 🛠️ Padding video_083 with black frames.
# 📂 Processing video: video_084
# 📂 Processing video: video_085
# 📂 Processing video: video_086
# 📂 Processing video: video_087
# 📂 Processing video: video_088
# 📂 Processing video: video_089
# 📂 Processing video: video_090
# 📂 Processing video: video_091
# 🛠️ Padding video_091 with black frames.
# 📂 Processing video: video_092
# 🛠️ Padding video_092 with black frames.
# 📂 Processing video: video_093
# 🛠️ Padding video_093 with black frames.
# 📂 Processing video: video_094
# 🛠️ Padding video_094 with black frames.
# 📂 Processing video: video_095
# 📂 Processing video: video_096
# 🛠️ Padding video_096 with black frames.
# 📂 Processing video: video_097
# 🛠️ Padding video_097 with black frames.
# 📂 Processing video: video_098
# 🛠️ Padding video_098 with black frames.
# 📂 Processing video: video_099
# 🛠️ Padding video_099 with black frames.
# 📂 Processing video: video_100
# 🛠️ Padding video_100 with black frames.
# 📂 Processing video: video_101
# 🛠️ Padding video_101 with black frames.
# 📂 Processing video: video_102
# 📂 Processing video: video_103
# 📂 Processing video: video_104
# 📂 Processing video: video_105
# 📂 Processing video: video_106
# 📂 Processing video: video_107
# 📂 Processing video: video_108
# 📂 Processing video: video_109
# 📂 Processing video: video_110
# 📂 Processing video: video_111
# 📂 Processing video: video_112
# 📂 Processing video: video_113
# 📂 Processing video: video_114
# 📂 Processing video: video_115
# 📂 Processing video: video_116
# 📂 Processing video: video_117
# 📂 Processing video: video_118
# 📂 Processing video: video_119
# 📂 Processing video: video_120
# 📂 Processing video: video_121
# 📂 Processing video: video_122
# 🛠️ Padding video_122 with black frames.
# 📂 Processing video: video_123
# 📂 Processing video: video_124
# 📂 Processing video: video_125
# 📂 Processing video: video_126
# 📂 Processing video: video_127
# 🛠️ Padding video_127 with black frames.
# 📂 Processing video: video_128
# 📂 Processing video: video_129
# 📂 Processing video: video_130
# 📂 Processing video: video_131
# 📂 Processing video: video_132
# 📂 Processing video: video_133
# 📂 Processing video: video_134
# 📂 Processing video: video_135
# 📂 Processing video: video_136
# 📂 Processing video: video_137
# 📂 Processing video: video_138
# 📂 Processing video: video_139
# 📂 Processing video: video_140
# 📂 Processing video: video_141
# 📂 Processing video: video_142
# 📂 Processing video: video_143
# 📂 Processing video: video_144
# 📂 Processing video: video_145
# 📂 Processing video: video_146
# 📂 Processing video: video_147
# 📂 Processing video: video_148
# 📂 Processing video: video_149
# 📂 Processing video: video_150
# 📂 Processing video: video_151
# 📂 Processing video: video_152
# 📂 Processing video: video_153
# 🛠️ Padding video_153 with black frames.
# 📂 Processing video: video_154
# 🛠️ Padding video_154 with black frames.
# 📂 Processing video: video_155
# 🛠️ Padding video_155 with black frames.
# 📂 Processing video: video_156
# 🛠️ Padding video_156 with black frames.
# 📂 Processing video: video_157
# 📂 Processing video: video_158
# 📂 Processing video: video_159
# 📂 Processing video: video_160
# 📂 Processing video: video_161
# 📂 Processing video: video_162
# 📂 Processing video: video_163
# 📂 Processing video: video_164
# 📂 Processing video: video_165
# 📂 Processing video: video_166
# 🛠️ Padding video_166 with black frames.
# 📂 Processing video: video_167
# 🛠️ Padding video_167 with black frames.
# 📂 Processing video: video_168
# 📂 Processing video: video_169
# 🛠️ Padding video_169 with black frames.
# 📂 Processing video: video_170
# 📂 Processing video: video_171
# 📂 Processing video: video_172
# 📂 Processing video: video_173
# 📂 Processing video: video_174
# 📂 Processing video: video_175
# 📂 Processing video: video_176
# 🛠️ Padding video_176 with black frames.
# 📂 Processing video: video_177
# 🛠️ Padding video_177 with black frames.
# 📂 Processing video: video_178
# 📂 Processing video: video_179
# 📂 Processing video: video_180
# 📂 Processing video: video_181
# 📂 Processing video: video_182
# 📂 Processing video: video_183
# 📂 Processing video: video_184
# 📂 Processing video: video_185
# 📂 Processing video: video_186
# 📂 Processing video: video_187
# 🛠️ Padding video_187 with black frames.
# 📂 Processing video: video_188
# 🛠️ Padding video_188 with black frames.
# 📂 Processing video: video_189
# 🛠️ Padding video_189 with black frames.
# 📂 Processing video: video_190
# 📂 Processing video: video_191
# 📂 Processing video: video_192
# 📂 Processing video: video_193
# 📂 Processing video: video_194
# 📂 Processing video: video_195
# 📂 Processing video: video_196
# 📂 Processing video: video_197
# 📂 Processing video: video_198
# 📂 Processing video: video_199
# 📂 Processing video: video_200
# 📂 Processing video: video_201
# 📂 Processing video: video_202
# 📂 Processing video: video_203
# 📂 Processing video: video_204
# 📂 Processing video: video_205
# 📂 Processing video: video_206
# 📂 Processing video: video_207
# 📂 Processing video: video_208
# 📂 Processing video: video_209
# 🛠️ Padding video_209 with black frames.
# 📂 Processing video: video_210
# 🛠️ Padding video_210 with black frames.
# 📂 Processing video: video_211
# 📂 Processing video: video_212
# 📂 Processing video: video_213
# 📂 Processing video: video_214
# 📂 Processing video: video_215
# 📂 Processing video: video_216
# 📂 Processing video: video_217
# 📂 Processing video: video_218
# 📂 Processing video: video_219
# 📂 Processing video: video_220
# 📂 Processing video: video_221
# 📂 Processing video: video_222
# 📂 Processing video: video_223
# 📂 Processing video: video_224
# 📂 Processing video: video_225
# 📂 Processing video: video_226
# 📂 Processing video: video_227
# 📂 Processing video: video_228
# 📂 Processing video: video_229
# 📂 Processing video: video_230
# 📂 Processing video: video_231
# 📂 Processing video: video_232
# 📂 Processing video: video_233
# 📂 Processing video: video_234
# 📂 Processing video: video_235
# 📂 Processing video: video_236
# 📂 Processing video: video_237
# 📂 Processing video: video_238
# 📂 Processing video: video_239
# 📂 Processing video: video_240
# 📂 Processing video: video_241
# 📂 Processing video: video_242
# 📂 Processing video: video_243
# 📂 Processing video: video_244
# 📂 Processing video: video_245
# 📂 Processing video: video_246
# 📂 Processing video: video_247
# 📂 Processing video: video_248
# 📂 Processing video: video_249
# 📂 Processing video: video_250
# 📂 Processing video: video_251
# 📂 Processing video: video_252
# 📂 Processing video: video_253
# 📂 Processing video: video_254
# 📂 Processing video: video_255
# 📂 Processing video: video_256
# 📂 Processing video: video_257
# 📂 Processing video: video_258
# 📂 Processing video: video_259
# 📂 Processing video: video_260
# 📂 Processing video: video_261
# 📂 Processing video: video_262
# 📂 Processing video: video_263
# 📂 Processing video: video_264
# 📂 Processing video: video_265
# 📂 Processing video: video_266
# 📂 Processing video: video_267
# 📂 Processing video: video_268
# 🛠️ Padding video_268 with black frames.
# 📂 Processing video: video_269
# 🛠️ Padding video_269 with black frames.
# 📂 Processing video: video_270
# 📂 Processing video: video_271
# 📂 Processing video: video_272
# 📂 Processing video: video_273
# 📂 Processing video: video_274
# 📂 Processing video: video_275
# 📂 Processing video: video_276
# 📂 Processing video: video_277
# 📂 Processing video: video_278
# 📂 Processing video: video_279
# 📂 Processing video: video_280
# 📂 Processing video: video_281
# 📂 Processing video: video_282
# 📂 Processing video: video_283
# 📂 Processing video: video_284
# 📂 Processing video: video_285
# 📂 Processing video: video_286
# 📂 Processing video: video_287
# 📂 Processing video: video_288
# 📂 Processing video: video_289
# 📂 Processing video: video_290
# ...
# 📂 Processing video: video_1164
# 🛠️ Padding video_1164 with black frames.
# 📂 Processing video: video_1165
# 📂 Processing video: video_1166
# 🛠️ Padding video_1166 with black frames.
# 📂 Processing video: video_1167
# 📂 Processing video: video_1168
# 🛠️ Padding video_1168 with black frames.
# 📂 Processing video: video_1169
# 📂 Processing video: video_1170
# 📂 Processing video: video_1171
# 🛠️ Padding video_1171 with black frames.
# 📂 Processing video: video_1172
# 📂 Processing video: video_1173
# 📂 Processing video: video_1174
# 🛠️ Padding video_1174 with black frames.
# 📂 Processing video: video_1175
# 🛠️ Padding video_1175 with black frames.
# 📂 Processing video: video_1176
# 📂 Processing video: video_1177
# 📂 Processing video: video_1178
# 🛠️ Padding video_1178 with black frames.
# 📂 Processing video: video_1179
# 📂 Processing video: video_1180
# 🛠️ Padding video_1180 with black frames.
# 📂 Processing video: video_1181
# 🛠️ Padding video_1181 with black frames.
# 📂 Processing video: video_1182
# 🛠️ Padding video_1182 with black frames.
# 📂 Processing video: video_1183
# 🛠️ Padding video_1183 with black frames.
# 📂 Processing video: video_1184
# 🛠️ Padding video_1184 with black frames.
# 📂 Processing video: video_1185
# 🛠️ Padding video_1185 with black frames.
# 📂 Processing video: video_1186
# 🛠️ Padding video_1186 with black frames.
# 📂 Processing video: video_1187
# 📂 Processing video: video_1188
# 🛠️ Padding video_1188 with black frames.
# 📂 Processing video: video_1189
# 🛠️ Padding video_1189 with black frames.
# 📂 Processing video: video_1190
# 📂 Processing video: video_1191
# 📂 Processing video: video_1192
# 🛠️ Padding video_1192 with black frames.
# 📂 Processing video: video_1193
# 📂 Processing video: video_1194
# 🛠️ Padding video_1194 with black frames.
# 📂 Processing video: video_1195
# 🛠️ Padding video_1195 with black frames.
# 📂 Processing video: video_1196
# 📂 Processing video: video_1197
# 📂 Processing video: video_1198
# 📂 Processing video: video_1199
# 🛠️ Padding video_1199 with black frames.
# 📂 Processing video: video_1200
# 📂 Processing video: video_1201
# 🛠️ Padding video_1201 with black frames.
# 📂 Processing video: video_1202
# 📂 Processing video: video_1203
# 📂 Processing video: video_1204
# 🛠️ Padding video_1204 with black frames.
# 📂 Processing video: video_1205
# 🛠️ Padding video_1205 with black frames.
# 📂 Processing video: video_1206
# 🛠️ Padding video_1206 with black frames.
# 📂 Processing video: video_1207
# 🛠️ Padding video_1207 with black frames.
# 📂 Processing video: video_1208
# 📂 Processing video: video_1209
# 📂 Processing video: video_1210
# 🛠️ Padding video_1210 with black frames.
# 📂 Processing video: video_1211
# 📂 Processing video: video_1212
# 📂 Processing video: video_1213
# 🛠️ Padding video_1213 with black frames.
# 📂 Processing video: video_1214
# 🛠️ Padding video_1214 with black frames.
# 📂 Processing video: video_1215
# 🛠️ Padding video_1215 with black frames.
# 📂 Processing video: video_1216
# 📂 Processing video: video_1217
# 📂 Processing video: video_1218
# 🛠️ Padding video_1218 with black frames.
# 📂 Processing video: video_1219
# 📂 Processing video: video_1220
# 🛠️ Padding video_1220 with black frames.
# 📂 Processing video: video_1221
# 🛠️ Padding video_1221 with black frames.
# 📂 Processing video: video_1222
# 📂 Processing video: video_1223
# 📂 Processing video: video_1224
# 📂 Processing video: video_1225
# 📂 Processing video: video_1226
# 🛠️ Padding video_1226 with black frames.
# 📂 Processing video: video_1227
# 📂 Processing video: video_1228
# 🛠️ Padding video_1228 with black frames.
# 📂 Processing video: video_1229
# 🛠️ Padding video_1229 with black frames.
# 📂 Processing video: video_1230
# 🛠️ Padding video_1230 with black frames.
# 📂 Processing video: video_1231
# 🛠️ Padding video_1231 with black frames.
# 📂 Processing video: video_1232
# 🛠️ Padding video_1232 with black frames.
# 📂 Processing video: video_1233
# 🛠️ Padding video_1233 with black frames.
# 📂 Processing video: video_1234
# 📂 Processing video: video_1235
# 📂 Processing video: video_1236
# 📂 Processing video: video_1237
# 📂 Processing video: video_1238
# 🛠️ Padding video_1238 with black frames.
# 📂 Processing video: video_1239
# 🛠️ Padding video_1239 with black frames.
# 📂 Processing video: video_1240
# 🛠️ Padding video_1240 with black frames.
# 📂 Processing video: video_1241
# 📂 Processing video: video_001
# 📂 Processing video: video_039
# 📂 Processing video: video_002
# 📂 Processing video: video_003
# 📂 Processing video: video_004
# 🛠️ Padding video_004 with black frames.
# 📂 Processing video: video_005
# 📂 Processing video: video_006
# 🛠️ Padding video_006 with black frames.
# 📂 Processing video: video_008
# 🛠️ Padding video_008 with black frames.
# 📂 Processing video: video_007
# 🛠️ Padding video_007 with black frames.
# 📂 Processing video: video_010
# 🛠️ Padding video_010 with black frames.
# 📂 Processing video: video_009
# 🛠️ Padding video_009 with black frames.
# 📂 Processing video: video_011
# 🛠️ Padding video_011 with black frames.
# 📂 Processing video: video_012
# 🛠️ Padding video_012 with black frames.
# 📂 Processing video: video_013
# 📂 Processing video: video_014
# 🛠️ Padding video_014 with black frames.
# 📂 Processing video: video_015
# 🛠️ Padding video_015 with black frames.
# 📂 Processing video: video_016
# 🛠️ Padding video_016 with black frames.
# 📂 Processing video: video_017
# 🛠️ Padding video_017 with black frames.
# 📂 Processing video: video_018
# 🛠️ Padding video_018 with black frames.
# 📂 Processing video: video_019
# 🛠️ Padding video_019 with black frames.
# 📂 Processing video: video_020
# 🛠️ Padding video_020 with black frames.
# 📂 Processing video: video_021
# 🛠️ Padding video_021 with black frames.
# 📂 Processing video: video_022
# 📂 Processing video: video_023
# 📂 Processing video: video_024
# 🛠️ Padding video_024 with black frames.
# 📂 Processing video: video_025
# 🛠️ Padding video_025 with black frames.
# 📂 Processing video: video_026
# 🛠️ Padding video_026 with black frames.
# 📂 Processing video: video_027
# 🛠️ Padding video_027 with black frames.
# 📂 Processing video: video_028
# 🛠️ Padding video_028 with black frames.
# 📂 Processing video: video_029
# 🛠️ Padding video_029 with black frames.
# 📂 Processing video: video_030
# 📂 Processing video: video_031
# 📂 Processing video: video_032
# 📂 Processing video: video_033
# 📂 Processing video: video_034
# 📂 Processing video: video_035
# 🛠️ Padding video_035 with black frames.
# 📂 Processing video: video_036
# 📂 Processing video: video_037
# 🛠️ Padding video_037 with black frames.
# 📂 Processing video: video_038
# 🛠️ Padding video_038 with black frames.
# 📂 Processing video: video_040
# 🛠️ Padding video_040 with black frames.
# 📂 Processing video: video_041
# 📂 Processing video: video_042
# 📂 Processing video: video_043
# 🛠️ Padding video_043 with black frames.
# 📂 Processing video: video_044
# 📂 Processing video: video_045
# 📂 Processing video: video_046
# 📂 Processing video: video_047
# 🛠️ Padding video_047 with black frames.
# 📂 Processing video: video_048
# 🛠️ Padding video_048 with black frames.
# 📂 Processing video: video_049
# 🛠️ Padding video_049 with black frames.
# 📂 Processing video: video_050
# 🛠️ Padding video_050 with black frames.
# 📂 Processing video: video_051
# 📂 Processing video: video_052
# 🛠️ Padding video_052 with black frames.
# 📂 Processing video: video_053
# 📂 Processing video: video_054
# 📂 Processing video: video_055
# 🛠️ Padding video_055 with black frames.
# 📂 Processing video: video_056
# 📂 Processing video: video_057
# 📂 Processing video: video_058
# 📂 Processing video: video_059
# 🛠️ Padding video_059 with black frames.
# 📂 Processing video: video_060
# 🛠️ Padding video_060 with black frames.
# 📂 Processing video: video_061
# 📂 Processing video: video_062
# 📂 Processing video: video_063
# 🛠️ Padding video_063 with black frames.
# 📂 Processing video: video_064
# 🛠️ Padding video_064 with black frames.
# 📂 Processing video: video_065
# 📂 Processing video: video_066
# 📂 Processing video: video_067
# 📂 Processing video: video_068
# 📂 Processing video: video_069
# 🛠️ Padding video_069 with black frames.
# 📂 Processing video: video_070
# 📂 Processing video: video_071
# 📂 Processing video: video_072
# 📂 Processing video: video_073
# 📂 Processing video: video_074
# 🛠️ Padding video_074 with black frames.
# 📂 Processing video: video_075
# 📂 Processing video: video_076
# 🛠️ Padding video_076 with black frames.
# 📂 Processing video: video_077
# 🛠️ Padding video_077 with black frames.
# 📂 Processing video: video_078
# 🛠️ Padding video_078 with black frames.
# 📂 Processing video: video_079
# 📂 Processing video: video_080
# 📂 Processing video: video_081
# 📂 Processing video: video_082
# 🛠️ Padding video_082 with black frames.
# 📂 Processing video: video_083
# 🛠️ Padding video_083 with black frames.
# 📂 Processing video: video_084
# 📂 Processing video: video_085
# 📂 Processing video: video_086
# 📂 Processing video: video_087
# 📂 Processing video: video_088
# 🛠️ Padding video_088 with black frames.
# 📂 Processing video: video_089
# 🛠️ Padding video_089 with black frames.
# 📂 Processing video: video_090
# 🛠️ Padding video_090 with black frames.
# 📂 Processing video: video_091
# 🛠️ Padding video_091 with black frames.
# 📂 Processing video: video_092
# 🛠️ Padding video_092 with black frames.
# 📂 Processing video: video_093
# 🛠️ Padding video_093 with black frames.
# 📂 Processing video: video_094
# 🛠️ Padding video_094 with black frames.
# 📂 Processing video: video_095
# 🛠️ Padding video_095 with black frames.
# 📂 Processing video: video_096
# 🛠️ Padding video_096 with black frames.
# 📂 Processing video: video_097
# 🛠️ Padding video_097 with black frames.
# 📂 Processing video: video_098
# 📂 Processing video: video_099
# 📂 Processing video: video_100
# 📂 Processing video: video_101
# 📂 Processing video: video_102
# 🛠️ Padding video_102 with black frames.
# 📂 Processing video: video_103
# 🛠️ Padding video_103 with black frames.
# 📂 Processing video: video_104
# 🛠️ Padding video_104 with black frames.
# 📂 Processing video: video_105
# 📂 Processing video: video_106
# 📂 Processing video: video_107
# 🛠️ Padding video_107 with black frames.
# 📂 Processing video: video_108
# 📂 Processing video: video_109
# 📂 Processing video: video_110
# 📂 Processing video: video_111
# 📂 Processing video: video_112
# 📂 Processing video: video_113
# 📂 Processing video: video_114
# 📂 Processing video: video_115
# 🛠️ Padding video_115 with black frames.
# 📂 Processing video: video_116
# 🛠️ Padding video_116 with black frames.
# 📂 Processing video: video_117
# 🛠️ Padding video_117 with black frames.
# 📂 Processing video: video_118
# 🛠️ Padding video_118 with black frames.
# 📂 Processing video: video_119
# 🛠️ Padding video_119 with black frames.
# 📂 Processing video: video_120
# 🛠️ Padding video_120 with black frames.
# 📂 Processing video: video_121
# 📂 Processing video: video_122
# 📂 Processing video: video_123
# 📂 Processing video: video_124
# 🛠️ Padding video_124 with black frames.
# 📂 Processing video: video_125
# 🛠️ Padding video_125 with black frames.
# 📂 Processing video: video_126
# 🛠️ Padding video_126 with black frames.
# 📂 Processing video: video_127
# 📂 Processing video: video_128
# 🛠️ Padding video_128 with black frames.
# 📂 Processing video: video_129
# 🛠️ Padding video_129 with black frames.
# 📂 Processing video: video_130
# 📂 Processing video: video_131
# 🛠️ Padding video_131 with black frames.
# 📂 Processing video: video_132
# 📂 Processing video: video_133
# 🛠️ Padding video_133 with black frames.
# 📂 Processing video: video_134
# 📂 Processing video: video_135
# 🛠️ Padding video_135 with black frames.
# 📂 Processing video: video_136
# 🛠️ Padding video_136 with black frames.
# 📂 Processing video: video_137
# 📂 Processing video: video_138
# 📂 Processing video: video_139
# 🛠️ Padding video_139 with black frames.
# 📂 Processing video: video_140
# 🛠️ Padding video_140 with black frames.
# 📂 Processing video: video_141
# 📂 Processing video: video_142
# 🛠️ Padding video_142 with black frames.
# 📂 Processing video: video_143
# 🛠️ Padding video_143 with black frames.
# 📂 Processing video: video_144
# 📂 Processing video: video_145
# 🛠️ Padding video_145 with black frames.
# 📂 Processing video: video_146
# 📂 Processing video: video_147
# 🛠️ Padding video_147 with black frames.
# 📂 Processing video: video_148
# 📂 Processing video: video_149
# 🛠️ Padding video_149 with black frames.
# 📂 Processing video: video_150
# 📂 Processing video: video_151
# 📂 Processing video: video_152
# 📂 Processing video: video_153
# 📂 Processing video: video_154
# 📂 Processing video: video_155
# 📂 Processing video: video_156
# 📂 Processing video: video_157
# 📂 Processing video: video_158
# 📂 Processing video: video_159
# 📂 Processing video: video_160
# 📂 Processing video: video_161
# 📂 Processing video: video_162
# 📂 Processing video: video_163
# 📂 Processing video: video_164
# 📂 Processing video: video_165
# 📂 Processing video: video_167
# 🛠️ Padding video_167 with black frames.
# 📂 Processing video: video_166
# 🛠️ Padding video_166 with black frames.
# 📂 Processing video: video_168
# 📂 Processing video: video_169
# 📂 Processing video: video_170
# 📂 Processing video: video_171
# 📂 Processing video: video_172
# 📂 Processing video: video_173
# 📂 Processing video: video_174
# 📂 Processing video: video_175
# 📂 Processing video: video_176
# 🛠️ Padding video_176 with black frames.
# 📂 Processing video: video_177
# 🛠️ Padding video_177 with black frames.
# 📂 Processing video: video_178
# 📂 Processing video: video_179
# 📂 Processing video: video_180
# 📂 Processing video: video_181
# 📂 Processing video: video_182
# 📂 Processing video: video_183
# 🛠️ Padding video_183 with black frames.
# 📂 Processing video: video_184
# 🛠️ Padding video_184 with black frames.
# 📂 Processing video: video_185
# 🛠️ Padding video_185 with black frames.
# 📂 Processing video: video_186
# 📂 Processing video: video_187
# 📂 Processing video: video_188
# 📂 Processing video: video_189
# 📂 Processing video: video_190
# 📂 Processing video: video_191
# 🛠️ Padding video_191 with black frames.
# 📂 Processing video: video_192
# 🛠️ Padding video_192 with black frames.
# 📂 Processing video: video_193
# 🛠️ Padding video_193 with black frames.
# 📂 Processing video: video_194
# 🛠️ Padding video_194 with black frames.
# 📂 Processing video: video_195
# 🛠️ Padding video_195 with black frames.
# 📂 Processing video: video_196
# 🛠️ Padding video_196 with black frames.
# 📂 Processing video: video_197
# 🛠️ Padding video_197 with black frames.
# 📂 Processing video: video_198
# 🛠️ Padding video_198 with black frames.
# 📂 Processing video: video_199
# 📂 Processing video: video_200
# 📂 Processing video: video_201
# 📂 Processing video: video_202
# 🛠️ Padding video_202 with black frames.
# 📂 Processing video: video_203
# 📂 Processing video: video_204
# 🛠️ Padding video_204 with black frames.
# 📂 Processing video: video_205
# 📂 Processing video: video_206
# 📂 Processing video: video_207
# 🛠️ Padding video_207 with black frames.
# 📂 Processing video: video_208
# 🛠️ Padding video_208 with black frames.
# 📂 Processing video: video_209
# 📂 Processing video: video_210
# 📂 Processing video: video_211
# 📂 Processing video: video_212
# 📂 Processing video: video_213
# 📂 Processing video: video_214
# 🛠️ Padding video_214 with black frames.
# 📂 Processing video: video_215
# 📂 Processing video: video_216
# 📂 Processing video: video_217
# 📂 Processing video: video_218
# 📂 Processing video: video_219
# 📂 Processing video: video_220
# 🛠️ Padding video_220 with black frames.
# 📂 Processing video: video_221
# 📂 Processing video: video_222
# 📂 Processing video: video_223
# 📂 Processing video: video_224
# 📂 Processing video: video_225
# 🛠️ Padding video_225 with black frames.
# 📂 Processing video: video_226
# 🛠️ Padding video_226 with black frames.
# 📂 Processing video: video_227
# 🛠️ Padding video_227 with black frames.
# 📂 Processing video: video_228
# 🛠️ Padding video_228 with black frames.
# 📂 Processing video: video_229
# 🛠️ Padding video_229 with black frames.
# 📂 Processing video: video_230
# 📂 Processing video: video_231
# 📂 Processing video: video_232
# 🛠️ Padding video_232 with black frames.
# 📂 Processing video: video_233
# 📂 Processing video: video_234
# 📂 Processing video: video_235
# 📂 Processing video: video_236
# 🛠️ Padding video_236 with black frames.
# 📂 Processing video: video_237
# 🛠️ Padding video_237 with black frames.
# 📂 Processing video: video_238
# 🛠️ Padding video_238 with black frames.
# 📂 Processing video: video_239
# 🛠️ Padding video_239 with black frames.
# 📂 Processing video: video_240
# 🛠️ Padding video_240 with black frames.
# 📂 Processing video: video_241
# 📂 Processing video: video_242
# 📂 Processing video: video_243
# 🛠️ Padding video_243 with black frames.
# ✅ Preprocessing complete!

# %%
import numpy as np
import glob
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# 📌 Define dataset path
DATA_PATH = "/content/drive/MyDrive/preprocessed"
CATEGORIES = ["normal", "rash"]

# 📌 Load file paths only (not the actual videos yet)
video_paths = []
labels = []

for category in CATEGORIES:
    video_files = glob.glob(f"{DATA_PATH}/{category}/*.npy")  # Get file paths
    label = 0 if category == "normal" else 1  # Assign labels

    for video in video_files:
        video_paths.append(video)
        labels.append(label)

# 📌 Convert labels to One-Hot Encoding
labels = to_categorical(labels, num_classes=2)

# 📌 Split file paths into train & test
train_videos, test_videos, y_train, y_test = train_test_split(video_paths, labels, test_size=0.2, random_state=42)

# 📌 Define a data generator to load files in batches
def data_generator(video_paths, labels, batch_size=16):
    while True:
        for i in range(0, len(video_paths), batch_size):
            batch_videos = video_paths[i:i + batch_size]
            batch_labels = labels[i:i + batch_size]

            # Load only the necessary videos
            X_batch = np.array([np.load(video) for video in batch_videos])
            y_batch = np.array(batch_labels)

            yield X_batch, y_batch

# ✅ Instead of loading all data, use generators
train_generator = data_generator(train_videos, y_train, batch_size=10)
test_generator = data_generator(test_videos, y_test, batch_size=10)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, LSTM, Dense, Dropout, TimeDistributed, GlobalAveragePooling2D, Input

# Define parameters
SEQUENCE_LENGTH = 15  # Number of frames per video
IMG_HEIGHT, IMG_WIDTH = 128, 128  # Using your existing frame size
CHANNELS = 3  # RGB images

# Define the model
model = Sequential([
    Input(shape=(SEQUENCE_LENGTH, IMG_HEIGHT, IMG_WIDTH, CHANNELS)),

    # CNN Feature Extraction
    TimeDistributed(Conv2D(32, (3, 3), activation='relu', padding='same')),
    TimeDistributed(MaxPooling2D((2, 2))),

    TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same')),
    TimeDistributed(MaxPooling2D((2, 2))),

    TimeDistributed(Conv2D(128, (3, 3), activation='relu', padding='same')),
    TimeDistributed(MaxPooling2D((2, 2))),

    TimeDistributed(Conv2D(256, (3, 3), activation='relu', padding='same')),
    TimeDistributed(MaxPooling2D((2, 2))),

    TimeDistributed(Conv2D(512, (3, 3), activation='relu', padding='same')),
    TimeDistributed(MaxPooling2D((2, 2))),

    TimeDistributed(GlobalAveragePooling2D()),

    LSTM(128, return_sequences=True),
    LSTM(64),

    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.3),

    Dense(2, activation='softmax')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 15, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 15, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 15, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 15, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 15, 32, 32,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 15, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 15, 16, 16,     │       295,168 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 15, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 15, 8, 8, 512)  │     1,180,160 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 15, 4, 4, 512)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 15, 512)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 15, 128)        │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,962,882 (7.49 MB)
#  Trainable params: 1,962,882 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(train_generator, epochs=10, steps_per_epoch=len(train_videos)//64,
                  validation_data=test_generator, validation_steps=len(test_videos)//64)
# Out:
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 707s 19s/step - accuracy: 0.6876 - loss: 0.6093 - val_accuracy: 0.6778 - val_loss: 0.6427
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 743s 20s/step - accuracy: 0.7837 - loss: 0.5417 - val_accuracy: 0.7889 - val_loss: 0.5422
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 744s 20s/step - accuracy: 0.7588 - loss: 0.5644 - val_accuracy: 0.7556 - val_loss: 0.6196
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 738s 20s/step - accuracy: 0.7685 - loss: 0.5739 - val_accuracy: 0.7778 - val_loss: 0.5147
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 706s 19s/step - accuracy: 0.7486 - loss: 0.5583 - val_accuracy: 0.7333 - val_loss: 0.5783
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 744s 20s/step - accuracy: 0.6997 - loss: 0.6096 - val_accuracy: 0.6889 - val_loss: 0.6061
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 709s 19s/step - accuracy: 0.7401 - loss: 0.5880 - val_accuracy: 0.7586 - val_loss: 0.5370
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 743s 20s/step - accuracy: 0.6736 - loss: 0.6306 - val_accuracy: 0.7667 - val_loss: 0.5561
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 742s 20s/step - accuracy: 0.6801 - loss: 0.6414 - val_accuracy: 0.7444 - val_loss: 0.5636
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 742s 20s/step - accuracy: 0.7050 - loss: 0.5953 - val_accuracy: 0.7444 - val_loss: 0.6006

# %%
model.save('/content/drive/MyDrive/rash_driving_model.keras')

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/rash_driving_model.keras')

# %%
import math
steps = math.ceil(len(test_videos) / 10)
model.evaluate(test_generator,steps=steps)
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step - accuracy: 0.7462 - loss: 0.5572
# [0.5761864185333252, 0.7413508892059326]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Adjust input shape based on your actual .npy file shape
INPUT_SHAPE = (15, 128, 128, 3)  # (frames, height, width, channels)

model2 = models.Sequential([
    layers.Input(shape=INPUT_SHAPE),

    layers.Conv3D(32, (3, 3, 3), activation='relu', padding='same'),
    layers.MaxPooling3D((1, 2, 2)),

    layers.Conv3D(64, (3, 3, 3), activation='relu', padding='same'),
    layers.MaxPooling3D((2, 2, 2)),

    layers.Conv3D(128, (3, 3, 3), activation='relu', padding='same'),
    layers.MaxPooling3D((2, 2, 2)),

    layers.Conv3D(256, (3, 3, 3), activation='relu', padding='same'),
    layers.MaxPooling3D((2, 2, 2)),

    # layers.Conv3D(512, (3, 3, 3), activation='relu', padding='same'),
    # layers.MaxPooling3D((2, 2, 2)),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')  # You used one-hot labels
])

# %%
model2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # since you're using to_categorical
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
h=model2.fit(
    train_generator,
    steps_per_epoch=len(train_videos) // 64,
    validation_data=test_generator,
    validation_steps=len(test_videos) // 10,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 19s 433ms/step - accuracy: 0.8460 - loss: 0.3506 - val_accuracy: 0.7923 - val_loss: 0.5176
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 19s 534ms/step - accuracy: 0.7998 - loss: 0.4436 - val_accuracy: 0.7789 - val_loss: 0.5432
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 16s 451ms/step - accuracy: 0.8376 - loss: 0.3615 - val_accuracy: 0.7621 - val_loss: 0.5389
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 18s 485ms/step - accuracy: 0.8421 - loss: 0.3638 - val_accuracy: 0.7973 - val_loss: 0.4948
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 16s 451ms/step - accuracy: 0.8095 - loss: 0.4319 - val_accuracy: 0.7588 - val_loss: 0.5888
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.7964 - loss: 0.4979 - val_accuracy: 0.7538 - val_loss: 0.5640
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 19s 531ms/step - accuracy: 0.8079 - loss: 0.4146 - val_accuracy: 0.8007 - val_loss: 0.4964
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 420ms/step - accuracy: 0.8795 - loss: 0.3503 - val_accuracy: 0.7956 - val_loss: 0.5043
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 17s 470ms/step - accuracy: 0.7628 - loss: 0.4654 - val_accuracy: 0.7973 - val_loss: 0.4921
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 418ms/step - accuracy: 0.8111 - loss: 0.3829 - val_accuracy: 0.7873 - val_loss: 0.5165
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 18s 507ms/step - accuracy: 0.8008 - loss: 0.4006 - val_accuracy: 0.7739 - val_loss: 0.5418
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.8573 - loss: 0.3230 - val_accuracy: 0.8007 - val_loss: 0.4688
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8111 - loss: 0.3934 - val_accuracy: 0.7688 - val_loss: 0.5626
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 420ms/step - accuracy: 0.8435 - loss: 0.3618 - val_accuracy: 0.8023 - val_loss: 0.5245
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 14s 385ms/step - accuracy: 0.7871 - loss: 0.4839 - val_accuracy: 0.7739 - val_loss: 0.5239
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 404ms/step - accuracy: 0.8255 - loss: 0.3739 - val_accuracy: 0.7973 - val_loss: 0.5056
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 19s 529ms/step - accuracy: 0.8669 - loss: 0.3041 - val_accuracy: 0.7822 - val_loss: 0.4820
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 20s 539ms/step - accuracy: 0.8423 - loss: 0.3499 - val_accuracy: 0.7655 - val_loss: 0.5318
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 21s 569ms/step - accuracy: 0.8730 - loss: 0.3108 - val_accuracy: 0.7772 - val_loss: 0.5476
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 400ms/step - accuracy: 0.8386 - loss: 0.3569 - val_accuracy: 0.7873 - val_loss: 0.5524
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 419ms/step - accuracy: 0.8474 - loss: 0.3451 - val_accuracy: 0.8057 - val_loss: 0.4744
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 18s 491ms/step - accuracy: 0.7574 - loss: 0.5410 - val_accuracy: 0.7923 - val_loss: 0.4926
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 414ms/step - accuracy: 0.8459 - loss: 0.3276 - val_accuracy: 0.7667 - val_loss: 0.6108
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 18s 493ms/step - accuracy: 0.8537 - loss: 0.3458 - val_accuracy: 0.7967 - val_loss: 0.5209
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 20s 557ms/step - accuracy: 0.8758 - loss: 0.3028 - val_accuracy: 0.7950 - val_loss: 0.5005
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 420ms/step - accuracy: 0.8865 - loss: 0.2845 - val_accuracy: 0.7521 - val_loss: 0.7012
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 17s 474ms/step - accuracy: 0.8321 - loss: 0.3688 - val_accuracy: 0.7822 - val_loss: 0.6453

# %%
model2.save('/content/drive/MyDrive/rash.keras')

# %%
from tensorflow.keras.models import load_model
model2 = load_model('/content/drive/MyDrive/rash.keras')

# %%
import math
steps = math.ceil(len(test_videos) / 10)
model2.evaluate(test_generator,steps=steps)
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.8115 - loss: 0.4598
# [0.47264060378074646, 0.8006590008735657]

# %%
import cv2
import numpy as np

def extract_frames_from_video(video_path, img_size=(128, 128), max_frames=15):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while len(frames) < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, img_size)
        frames.append(frame)
    cap.release()

    # Pad if too short
    while len(frames) < max_frames:
        frames.append(np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8))

    return np.array(frames)
def predict_video_class(video_path):
    frames = extract_frames_from_video(video_path)  # shape: (30, 64, 64, 3)
    input_data = np.expand_dims(frames, axis=0)  # shape: (1, 30, 64, 64, 3)

    prediction = model2.predict(input_data)
    label = "Rash Driving" if prediction[0][0] > 0.5 else "Normal Driving"
    print(f"Prediction: {label} (Confidence: {prediction[0][0]:.2f})")
predict_video_class('/content/drive/MyDrive/truePositive.mp4')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Prediction: Normal Driving (Confidence: 0.01)

# %%
import cv2
import numpy as np

def extract_frames_from_video(video_path, img_size=(128, 128), max_frames=15):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while len(frames) < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, img_size)
        frames.append(frame)
    cap.release()

    # Pad if too short
    while len(frames) < max_frames:
        frames.append(np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8))

    return np.array(frames)
def predict_video_class(video_path):
    frames = extract_frames_from_video(video_path)  # shape: (30, 64, 64, 3)
    input_data = np.expand_dims(frames, axis=0)  # shape: (1, 30, 64, 64, 3)

    prediction = model2.predict(input_data)
    label = "Rash Driving" if prediction[0][0] > 0.5 else "Normal Driving"
    print(f"Prediction: {label} (Confidence: {prediction[0][0]:.2f})")
predict_video_class('/content/drive/MyDrive/trueNegative.mp4')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Prediction: Rash Driving (Confidence: 0.90)

# %%
import cv2
import numpy as np

def extract_frames_from_video(video_path, img_size=(128, 128), max_frames=15):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while len(frames) < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, img_size)
        frames.append(frame)
    cap.release()

    # Pad if too short
    while len(frames) < max_frames:
        frames.append(np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8))

    return np.array(frames)
def predict_video_class(video_path):
    frames = extract_frames_from_video(video_path)  # shape: (30, 64, 64, 3)
    input_data = np.expand_dims(frames, axis=0)  # shape: (1, 30, 64, 64, 3)

    prediction = model2.predict(input_data)
    label = "Rash Driving" if prediction[0][0] > 0.5 else "Normal Driving"
    print(f"Prediction: {label} (Confidence: {prediction[0][0]:.2f})")
predict_video_class('/content/drive/MyDrive/falseNegative.mp4')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Prediction: Normal Driving (Confidence: 0.00)

# %%
import cv2
import os

# Path to your video file
video_path = "/content/drive/MyDrive/falsepositive.mp4"  # Replace with your video file path
output_folder = "/content/drive/MyDrive/out1"   # Folder to save extracted frames

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video was opened successfully
if not cap.isOpened():
    print("Error: Couldn't open video.")
    exit()

frame_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break  # End of video

    # Save the current frame as an image
    frame_filename = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_filename, frame)

    # Increment frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f"Extracted {frame_count} frames from the video.")
# Out:
# Extracted 169 frames from the video.

# %%
import cv2
import os

# Path to your video file
video_path = "/content/drive/MyDrive/falseNegative.mp4"  # Replace with your video file path
output_folder = "/content/drive/MyDrive/out2"   # Folder to save extracted frames

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video was opened successfully
if not cap.isOpened():
    print("Error: Couldn't open video.")
    exit()

frame_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break  # End of video

    # Save the current frame as an image
    frame_filename = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_filename, frame)

    # Increment frame count
    frame_count += 1

# Release the video capture object
cap.release()

print(f"Extracted {frame_count} frames from the video.")
# Out:
# Extracted 77 frames from the video.
